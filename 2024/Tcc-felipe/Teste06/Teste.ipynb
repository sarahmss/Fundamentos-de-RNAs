# %%
import os

os.chdir("./content")

lm_dir = "tf-levenberg-marquardt"
if not os.path.exists(lm_dir):
  # !git clone https://github.com/fabiodimarco/$lm_dir

os.chdir(lm_dir)

# %%
# !pip install --upgrade pip
# !pip install tensorflow 
# !pip install openpyxl
# Out:
# Requirement already satisfied: pip in /usr/local/python/3.10.13/lib/python3.10/site-packages (23.3.2)
# Requirement already satisfied: tensorflow in /usr/local/python/3.10.13/lib/python3.10/site-packages (2.15.0.post1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (1.26.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (0.35.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.26.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/codespace/.local/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)
# Requirement already satisfied: openpyxl in /usr/local/python/3.10.13/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/python/3.10.13/lib/python3.10/site-packages (from openpyxl) (1.1.0)

# %%
import numpy as np
import pandas as pd
from scipy.stats import zscore
from sklearn.preprocessing import MaxAbsScaler

def peaks(grid):
    x = np.linspace(-2, 2, grid)
    y = np.linspace(-2, 2, grid)
    x, y = np.meshgrid(x, y)
    z = 3*(1-x)**2 * np.exp(-(x**2) - (y+1)**2) - 10*(x/5 - x**3 - y**5) * np.exp(-x**2 - y**2) - 1/3 * np.exp(-(x+1)**2 - y**2)
    return x, y, z

def create_dataframe(grid):
   x, y, z = peaks(grid)
   data = {'X': x.flatten(), 'Y': y.flatten(), 'Z': z.flatten()}
   df = pd.DataFrame(data)
   return df

# %%
df_25 = create_dataframe(grid=5)
df_1000 = create_dataframe(grid=32)

# %%
def split_df(df):
    # df = df.sample(frac=1).reset_index(drop=True)  # Randomiza as linhas
    _input = np.vstack([df['X'], df['Y']]).T
    _output = np.array(df['Z'])
    return (_input, _output)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import levenberg_marquardt as lm
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
from sklearn.metrics import r2_score, mean_squared_error
from keras import regularizers
from keras import initializers

class TrainWithSmallDataset:
    def __init__(self, batch_size=1000, store=25):
        self.batch_size = batch_size
        self.betters = []
        self.store = store

    def create_dataset(self, input, output):
      input = tf.expand_dims(tf.cast(input, tf.float32), axis=-1)
      output = tf.expand_dims(tf.cast(output, tf.float32), axis=-1)

      dataset = tf.data.Dataset.from_tensor_slices((input, output))
      dataset = dataset.shuffle(len(input))
      dataset = dataset.batch(self.batch_size).cache()
      dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
      return (dataset, input, output)


    def split_dataset(self, input, output, sup_input, sup_output):

      input_train, input_vt, output_train, output_vt = train_test_split(input, output, test_size=0.3, shuffle = True)
      input_val, input_test, output_val, output_test = train_test_split(input_vt, output_vt, test_size=0.5, shuffle = True)

      self.train_dataset, self.train_input, self.train_output = self.create_dataset(input_train, output_train)
      self.val_dataset, self.val_input, self.val_output = self.create_dataset(input_val, output_val)
      self.test_dataset, self.test_input, self.test_output = self.create_dataset(input_test, output_test)
      self.vt_dataset, self.vt_input, self.vt_output = self.create_dataset(input_vt, output_vt)
      self.sup_dataset, self.sup_input, self.sup_output = self.create_dataset(sup_input, sup_output)
      self.dataset, self.input, self.output = self.create_dataset(input, output)

      self._train = (input_train, output_train)
      self._vt = (input_vt, output_vt)
      self._val = (input_val, output_val)
      self._test = (input_test, output_test)

    def create_model(self, input_size=2, sumary=False):
      regularizer = regularizers.L2(0.2)
      initializer = initializers.RandomUniform(minval=-0.5, maxval=0.5, seed=np.random.randint(1, 10000))

      self.model = tf.keras.Sequential([
          tf.keras.layers.Dense(30,
                                activation='tanh',
                                input_shape=(input_size,),
                                kernel_regularizer=regularizer,
                                kernel_initializer=initializer,
                                ),
          tf.keras.layers.Dense(16,
                                activation='tanh',
                                kernel_regularizer=regularizer,
                                kernel_initializer=initializer,
                                ),
          tf.keras.layers.Dense(1,
                                activation='linear',
                                kernel_regularizer=regularizer,
                                kernel_initializer=initializer,
        )])

      if (sumary == True):
        self.model.summary()

      self.model.compile(
          optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
          loss=tf.keras.losses.MeanSquaredError())

      self.lm_model = lm.ModelWrapper(
          tf.keras.models.clone_model(self.model))

      self.lm_model.compile(
          optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
          loss=lm.MeanSquaredError())

    def train_using_lm(self, train_dataset, epochs=1000):
      early_stopping_monitor = EarlyStopping(monitor='val_loss',
                                              patience=6,
                                              restore_best_weights=True)

      t2_start = time.perf_counter()
      self.results = self.lm_model.fit(train_dataset,
                                            epochs=epochs,
                                            validation_data=self.val_dataset,
                                            callbacks=[early_stopping_monitor],
                                            verbose=0)
      t2_stop = time.perf_counter()
      print("Elapsed time: ", t2_stop - t2_start)
      print ("Stopped at epoch: ", early_stopping_monitor.stopped_epoch)

    def get_metrics(self):
          self.sup_prediction = self.lm_model.predict(self.sup_input)
          self.test_prediction = self.lm_model.predict(self.test_input)

          pred = self.lm_model.predict(self.input).flatten()
          test_pred = self.test_prediction.flatten()
          val_pred = self.lm_model.predict(self.val_input).flatten()
          vt_pred = self.lm_model.predict(self.vt_input).flatten()
          sup_pred = self.sup_prediction.flatten()

          r2 = r2_score(self.output, pred)
          r2_test = r2_score(self.test_output, test_pred)
          r2_val = r2_score(self.val_output, val_pred)
          r2_vt = r2_score(self.vt_output, vt_pred)
          r2_sup = r2_score(self.sup_output, sup_pred)

          mse = mean_squared_error(self.output, pred)
          mse_test = mean_squared_error(self.test_output, test_pred)
          mse_val = mean_squared_error(self.val_output, val_pred)
          mse_vt = mean_squared_error(self.vt_output, vt_pred)
          mse_sup = mean_squared_error(self.sup_output, sup_pred)

          metrics = {
                          'r2': r2,
                          'r2_sup': r2_sup,
                          'r2_test': r2_test,
                          'r2_val': r2_val,
                          'r2_vt': r2_vt,
                          'mse': mse,
                          'mse_sup': mse_sup,
                          'mse_test': mse_test,
                          'mse_val': mse_val,
                          'mse_vt': mse_vt
                          }

          return metrics


    def plot_results(self):
      fig = plt.figure(figsize=(18, 6))
      ax0 = fig.add_subplot(1, 3, 1, projection='3d')
      ax2 = fig.add_subplot(1, 3, 2, projection='3d')
      ax1 = fig.add_subplot(1, 3, 3)

      ax0.set_title('Superficie Fit')
      ax0.scatter(self.sup_input[:, 0], self.sup_input[:, 1], self.sup_prediction, c='r', marker='s', label="lm")
      ax0.scatter(self.sup_input[:, 0], self.sup_input[:, 1], self.sup_output, c='b', marker='o', label="reference")
      ax0.legend()

      ax2.set_title('Teste Fit')
      ax2.scatter(self.test_input[:, 0], self.test_input[:, 1], self.test_prediction, c='r', marker='s', label="lm")
      ax2.scatter(self.test_input[:, 0], self.test_input[:, 1], self.test_output, c='b', marker='o', label="reference")
      ax2.legend()

      ax1.plot(self.results.history['loss'], label='Erro Treino')
      ax1.plot(self.results.history['val_loss'], label='Erro validação')
      ax1.set_title('Histórico de Treinamento')
      ax1.set_ylabel('Função de Custo')
      ax1.set_xlabel('Épocas de Treinamento')
      ax1.legend(['Erro Treino', 'Erro validação'])

      return(fig)
# Out:
# 2024-01-29 23:32:48.003765: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-29 23:32:48.064900: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-29 23:32:48.064947: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-29 23:32:48.066700: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-29 23:32:48.078058: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-29 23:32:48.079064: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-29 23:32:49.267132: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from keras import saving
from keras import models
import pickle

class Tester:
  def __init__(self, run_times=500, dataset_run_times=10):
    self.run_times = run_times
    self.better_metrics = {}
    self.dataset_run_times = dataset_run_times
    self.input_25, self.output_25 = split_df(df_25)
    self.input_1000, self.output_1000 = split_df(df_1000)
    self.weightsFile 

  def PrepareTraining(self):
    trainer = TrainWithSmallDataset()
    trainer.split_dataset(self.input_25, self.output_25, self.input_1000, self.output_1000)
    return (trainer)

  def Train(self, trainer, epochs=1000):
    trainer.create_model()
    trainer.train_using_lm(trainer.train_dataset, epochs=epochs)
    return(trainer.get_metrics(), trainer.lm_model)

  def SaveModelWeights(self, model, fileName):
    path = f"../models/{fileName}.keras"
    open(path,'w').close()
    model.save_weights(path)
  
  def LoadModelWeights(self, model, fileName):
    path = f"../models/{fileName}.keras"
    model.load_weights(path)

  
  def SaveFigs(self, trainer, fileName):
    path = f"../results/{fileName}.png" 
    open(path,'w').close()
    figure = trainer.plot_results()
    figure.savefig(path)
    plt.close(figure)

  def SaveDataset(self, trainer, fileName):
    path = f"../dataset/{fileName}.pkl" 
    with open(path, 'wb') as f:
      pickle.dump((trainer._train, trainer._vt, trainer._val, trainer._test), f)
  
  def LoadDataset(self, fileName, trainer):
    path = f"../dataset/{fileName}.pkl" 
    with open(path, 'rb') as f:
      _train, _vt, _val, _test = pickle.load(f)
    trainer._train, trainer._vt, trainer._val, trainer._test = _train, _vt, _val, _test

  def LoopWeights(self, sort_by, model_boundarie, trainer, j=0):
    better_model = 0
    for i in range(self.run_times):
      print (f"+++++++++++ Dataset [{j + 1}] | {i + 1} ++++++++++++++++++")
      metrics, model = self.Train(trainer)
      if (metrics[sort_by] <= model_boundarie): # should be >= to acsending metrics
        fileName = f"model_{j}_{better_model}"
        self.SaveModelWeights(model, fileName)
        self.SaveFigs(trainer, fileName)
        self.better_metrics[fileName] = metrics
        better_model += 1
              

  # brief: for each dataset
  def LoopDataset(self, sort_by, model_boundarie):
    for j in range(self.dataset_run_times):
      trainer = self.PrepareTraining() # split dataset
      self.SaveDataset(trainer, f"dataset_{j}")
      self.LoopWeights(sort_by, model_boundarie, trainer, j)

  def DisplayBetterResults(self, sort_by):
    df = pd.DataFrame.from_dict(self.better_metrics)
    df = df.transpose()
    df = df.sort_values([sort_by])
    display(df)
    excel_path = '../results/metrics.xlsx'
    df.to_excel(excel_path, index=False)
    print(f"DataFrame salvo em {excel_path}")

# %% [markdown]
# # Treinando com 25 dados

# %%
tester = Tester(run_times=100, dataset_run_times=0)

# %%
trainer = tester.PrepareTraining()
tester.LoadDataset("dataset_14", trainer)
tester.LoopWeights(sort_by='mse_sup', model_boundarie=2.5, trainer=trainer)
# Out:
# +++++++++++ Dataset [1] | 1 ++++++++++++++++++
# Elapsed time:  0.4506061980000595
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 2 ++++++++++++++++++
# Elapsed time:  0.5469138720000046
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# +++++++++++ Dataset [1] | 3 ++++++++++++++++++
# Elapsed time:  0.5341333460000897
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 4 ++++++++++++++++++
# Elapsed time:  0.46384320500055765
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 5 ++++++++++++++++++
# Elapsed time:  0.4620744250005373
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# +++++++++++ Dataset [1] | 6 ++++++++++++++++++
# Elapsed time:  0.5660074090001217
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 7 ++++++++++++++++++
# Elapsed time:  0.49198746100046264
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 8 ++++++++++++++++++
# Elapsed time:  0.8646921099998508
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 9 ++++++++++++++++++
# Elapsed time:  0.5117413320003834
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [1] | 10 ++++++++++++++++++
# Elapsed time:  0.4269766029992752
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 11 ++++++++++++++++++
# Elapsed time:  0.5269650849995742
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 12 ++++++++++++++++++
# Elapsed time:  0.5318979630001195
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 13 ++++++++++++++++++
# Elapsed time:  0.5519306039996081
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 14 ++++++++++++++++++
# Elapsed time:  0.4928606299999956
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 15 ++++++++++++++++++
# Elapsed time:  0.5308693110000604
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 16 ++++++++++++++++++
# Elapsed time:  0.5808678180001152
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 17 ++++++++++++++++++
# Elapsed time:  0.46348281300015515
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 18 ++++++++++++++++++
# Elapsed time:  0.5043477399995027
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 19 ++++++++++++++++++
# Elapsed time:  0.7532354489994759
# Stopped at epoch:  11
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 20 ++++++++++++++++++
# Elapsed time:  0.5347379140002886
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# +++++++++++ Dataset [1] | 21 ++++++++++++++++++
# Elapsed time:  0.5300937459996931
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 22 ++++++++++++++++++
# Elapsed time:  0.5369719620002797
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 23 ++++++++++++++++++
# Elapsed time:  0.5339140850001058
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 24 ++++++++++++++++++
# Elapsed time:  0.5333297470006073
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 25 ++++++++++++++++++
# Elapsed time:  0.5778869039995698
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 264ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [1] | 26 ++++++++++++++++++
# Elapsed time:  0.4791973350002081
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 27 ++++++++++++++++++
# Elapsed time:  0.5153717359999064
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 28 ++++++++++++++++++
# Elapsed time:  0.4902155829995536
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 29 ++++++++++++++++++
# Elapsed time:  0.5373815689999901
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 30 ++++++++++++++++++
# Elapsed time:  0.49493208500007313
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 31 ++++++++++++++++++
# Elapsed time:  0.49990230399998836
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 32 ++++++++++++++++++
# Elapsed time:  0.4548550389999946
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 33 ++++++++++++++++++
# Elapsed time:  0.5078020870005275
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 34 ++++++++++++++++++
# Elapsed time:  0.40073956200012617
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 35 ++++++++++++++++++
# Elapsed time:  0.5876658480001424
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 36 ++++++++++++++++++
# Elapsed time:  0.578611015000206
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 37 ++++++++++++++++++
# Elapsed time:  0.48513938799987955
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 38 ++++++++++++++++++
# Elapsed time:  0.5393362869999692
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 39 ++++++++++++++++++
# Elapsed time:  0.4807404350003708
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 40 ++++++++++++++++++
# Elapsed time:  0.4801664830001755
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 41 ++++++++++++++++++
# Elapsed time:  0.6585751229995367
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 42 ++++++++++++++++++
# Elapsed time:  0.4771734269997978
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [1] | 43 ++++++++++++++++++
# Elapsed time:  0.5017816999998104
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 44 ++++++++++++++++++
# Elapsed time:  0.5277140119997057
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [1] | 45 ++++++++++++++++++
# Elapsed time:  0.7958033839995551
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 46 ++++++++++++++++++
# Elapsed time:  0.49124733900043793
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 47 ++++++++++++++++++
# Elapsed time:  0.5282166110000617
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 48 ++++++++++++++++++
# Elapsed time:  0.4671653069999593
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 49 ++++++++++++++++++
# Elapsed time:  0.851956756000618
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 50 ++++++++++++++++++
# Elapsed time:  0.5252737299997534
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 51 ++++++++++++++++++
# Elapsed time:  0.6103624700008368
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 52 ++++++++++++++++++
# Elapsed time:  0.5155351329995028
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 53 ++++++++++++++++++
# Elapsed time:  0.5270780549999472
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 54 ++++++++++++++++++
# Elapsed time:  0.46342135000031703
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 55 ++++++++++++++++++
# Elapsed time:  0.607629131000067
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 56 ++++++++++++++++++
# Elapsed time:  0.5324699029997646
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 57 ++++++++++++++++++
# Elapsed time:  0.54795670600015
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 58 ++++++++++++++++++
# Elapsed time:  0.523288283000511
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 59 ++++++++++++++++++
# Elapsed time:  0.49684700800025894
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 60 ++++++++++++++++++
# Elapsed time:  0.5118319389994213
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 61 ++++++++++++++++++
# Elapsed time:  0.5367418140003792
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 62 ++++++++++++++++++
# Elapsed time:  0.4930783950003388
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 63 ++++++++++++++++++
# Elapsed time:  0.492219662000025
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [1] | 64 ++++++++++++++++++
# Elapsed time:  0.5415312949999134
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 65 ++++++++++++++++++
# Elapsed time:  0.48286197600009473
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 66 ++++++++++++++++++
# Elapsed time:  0.8962864320001245
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [1] | 67 ++++++++++++++++++
# Elapsed time:  0.4831180020000829
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [1] | 68 ++++++++++++++++++
# Elapsed time:  0.47811859200010076
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 69 ++++++++++++++++++
# Elapsed time:  0.8726476570000159
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 70 ++++++++++++++++++
# Elapsed time:  0.5742384659997697
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [1] | 71 ++++++++++++++++++
# Elapsed time:  0.5183800899994822
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# +++++++++++ Dataset [1] | 72 ++++++++++++++++++
# Elapsed time:  0.49306357800014666
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [1] | 73 ++++++++++++++++++
# Elapsed time:  0.5230194989999291
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [1] | 74 ++++++++++++++++++
# Elapsed time:  0.599459349999961
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 75 ++++++++++++++++++
# Elapsed time:  0.5528713120002067
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 76 ++++++++++++++++++
# Elapsed time:  0.7968817680002758
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 77 ++++++++++++++++++
# Elapsed time:  0.48900769499960006
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 78 ++++++++++++++++++
# Elapsed time:  0.5117656439997518
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [1] | 79 ++++++++++++++++++
# Elapsed time:  0.5244983499997034
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# +++++++++++ Dataset [1] | 80 ++++++++++++++++++
# Elapsed time:  0.573553967999942
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 81 ++++++++++++++++++
# Elapsed time:  0.4780228529998567
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 82 ++++++++++++++++++
# Elapsed time:  0.5055209909996847
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [1] | 83 ++++++++++++++++++
# Elapsed time:  0.5659920819998661
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 84 ++++++++++++++++++
# Elapsed time:  0.4976877789995342
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 85 ++++++++++++++++++
# Elapsed time:  0.5199937750003301
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [1] | 86 ++++++++++++++++++
# Elapsed time:  0.5204417780005315
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 87 ++++++++++++++++++
# Elapsed time:  0.5093515389999084
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 88 ++++++++++++++++++
# Elapsed time:  0.5822995819999051
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 89 ++++++++++++++++++
# Elapsed time:  0.591657679000491
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 90 ++++++++++++++++++
# Elapsed time:  0.7778064329995686
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 91 ++++++++++++++++++
# Elapsed time:  0.5137153830000898
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 92 ++++++++++++++++++
# Elapsed time:  0.5355986810000104
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 93 ++++++++++++++++++
# Elapsed time:  0.5710661529992649
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 94 ++++++++++++++++++
# Elapsed time:  0.45793754100031947
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [1] | 95 ++++++++++++++++++
# Elapsed time:  0.5219484999997803
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [1] | 96 ++++++++++++++++++
# Elapsed time:  0.6024891940005546
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# +++++++++++ Dataset [1] | 97 ++++++++++++++++++
# Elapsed time:  0.5079010219997144
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 98 ++++++++++++++++++
# Elapsed time:  0.506003598999996
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 99 ++++++++++++++++++
# Elapsed time:  0.5122144629995091
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 100 ++++++++++++++++++
# Elapsed time:  0.5193726750003407
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step

# %%
tester.DisplayBetterResults('mse_sup')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_186464/3031367525.py in ?()
# ----> 1 tester.DisplayBetterResults('mse_sup')
#
# /tmp/ipykernel_186464/681117313.py in ?(self, sort_by)
#      66   def DisplayBetterResults(self, sort_by):
#      67     df = pd.DataFrame.from_dict(self.better_metrics)
#      68     df = df.transpose()
# ---> 69     df = df.sort_values([sort_by])
#      70     display(df)
#      71     excel_path = '../results/metrics.xlsx'
#      72     df.to_excel(excel_path, index=False)
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6940             )
#    6941         elif len(by):
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#    6947             if key is not None:
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
#    1841         elif self._is_level_reference(key, axis=axis):
#    1842             values = self.axes[axis].get_level_values(key)._values
#    1843         else:
# -> 1844             raise KeyError(key)
#    1845
#    1846         # Check for duplicates
#    1847         if values.ndim > 1:
#
# KeyError: 'mse_sup'
