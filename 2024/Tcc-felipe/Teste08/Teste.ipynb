# %%
import os

os.chdir("./content")

lm_dir = "tf-levenberg-marquardt"
if not os.path.exists(lm_dir):
  # !git clone https://github.com/fabiodimarco/$lm_dir

os.chdir(lm_dir)

# %%
# !pip install --upgrade pip
# !pip install tensorflow 
# !pip install openpyxl
# Out:
# Requirement already satisfied: pip in /usr/local/python/3.10.13/lib/python3.10/site-packages (23.3.2)
# Requirement already satisfied: tensorflow in /usr/local/python/3.10.13/lib/python3.10/site-packages (2.15.0.post1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (1.26.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (0.35.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.26.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/codespace/.local/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)
# Requirement already satisfied: openpyxl in /usr/local/python/3.10.13/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/python/3.10.13/lib/python3.10/site-packages (from openpyxl) (1.1.0)

# %%
import numpy as np
import pandas as pd
from scipy.stats import zscore
from sklearn.preprocessing import MaxAbsScaler

def peaks(grid):
    x = np.linspace(-2, 2, grid)
    y = np.linspace(-2, 2, grid)
    x, y = np.meshgrid(x, y)
    z = 3*(1-x)**2 * np.exp(-(x**2) - (y+1)**2) - 10*(x/5 - x**3 - y**5) * np.exp(-x**2 - y**2) - 1/3 * np.exp(-(x+1)**2 - y**2)
    return x, y, z

def create_dataframe(grid):
   x, y, z = peaks(grid)
   data = {'X': x.flatten(), 'Y': y.flatten(), 'Z': z.flatten()}
   df = pd.DataFrame(data)
   return df

# %%
df_25 = create_dataframe(grid=5)
df_1000 = create_dataframe(grid=32)

# %%
def split_df(df):
    # df = df.sample(frac=1).reset_index(drop=True)  # Randomiza as linhas
    _input = np.vstack([df['X'], df['Y']]).T
    _output = np.array(df['Z'])
    return (_input, _output)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import levenberg_marquardt as lm
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
from sklearn.metrics import r2_score, mean_squared_error
from keras import regularizers
from keras import initializers

class TrainWithSmallDataset:
    def __init__(self, batch_size=1000, store=25):
        self.batch_size = batch_size
        self.betters = []
        self.store = store

    def create_dataset(self, input, output):
      input = tf.expand_dims(tf.cast(input, tf.float32), axis=-1)
      output = tf.expand_dims(tf.cast(output, tf.float32), axis=-1)

      dataset = tf.data.Dataset.from_tensor_slices((input, output))
      dataset = dataset.shuffle(len(input))
      dataset = dataset.batch(self.batch_size).cache()
      dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
      return (dataset, input, output)


    def split_dataset(self, input, output, sup_input, sup_output):

      input_train, input_vt, output_train, output_vt = train_test_split(input, output, test_size=0.3, shuffle = True)
      input_val, input_test, output_val, output_test = train_test_split(input_vt, output_vt, test_size=0.5, shuffle = True)

      self.train_dataset, self.train_input, self.train_output = self.create_dataset(input_train, output_train)
      self.val_dataset, self.val_input, self.val_output = self.create_dataset(input_val, output_val)
      self.test_dataset, self.test_input, self.test_output = self.create_dataset(input_test, output_test)
      self.vt_dataset, self.vt_input, self.vt_output = self.create_dataset(input_vt, output_vt)
      self.sup_dataset, self.sup_input, self.sup_output = self.create_dataset(sup_input, sup_output)
      self.dataset, self.input, self.output = self.create_dataset(input, output)

      self._train = (input_train, output_train)
      self._vt = (input_vt, output_vt)
      self._val = (input_val, output_val)
      self._test = (input_test, output_test)

    def create_model(self, input_size=2, sumary=False):
      regularizer = regularizers.L2(0.2)
      initializer = initializers.RandomUniform(minval=-0.5, maxval=0.5, seed=np.random.randint(1, 10000))

      self.model = tf.keras.Sequential([
          tf.keras.layers.Dense(30,
                                activation='tanh',
                                input_shape=(input_size,),
                                kernel_regularizer=regularizer,
                                kernel_initializer=initializer,
                                ),
          tf.keras.layers.Dense(16,
                                activation='tanh',
                                kernel_regularizer=regularizer,
                                kernel_initializer=initializer,
                                ),
          tf.keras.layers.Dense(1,
                                activation='linear',
                                kernel_regularizer=regularizer,
                                kernel_initializer=initializer,
        )])

      if (sumary == True):
        self.model.summary()

      self.model.compile(
          optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
          loss=tf.keras.losses.MeanSquaredError())

      self.lm_model = lm.ModelWrapper(
          tf.keras.models.clone_model(self.model))

      self.lm_model.compile(
          optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
          loss=lm.MeanSquaredError())

    def train_using_lm(self, train_dataset, epochs=1000):
      early_stopping_monitor = EarlyStopping(monitor='val_loss',
                                              patience=6,
                                              restore_best_weights=True)

      t2_start = time.perf_counter()
      self.results = self.lm_model.fit(train_dataset,
                                            epochs=epochs,
                                            validation_data=self.val_dataset,
                                            callbacks=[early_stopping_monitor],
                                            verbose=0)
      t2_stop = time.perf_counter()
      print("Elapsed time: ", t2_stop - t2_start)
      print ("Stopped at epoch: ", early_stopping_monitor.stopped_epoch)

    def get_metrics(self):
          self.sup_prediction = self.lm_model.predict(self.sup_input)
          self.test_prediction = self.lm_model.predict(self.test_input)

          pred = self.lm_model.predict(self.input).flatten()
          test_pred = self.test_prediction.flatten()
          val_pred = self.lm_model.predict(self.val_input).flatten()
          vt_pred = self.lm_model.predict(self.vt_input).flatten()
          sup_pred = self.sup_prediction.flatten()

          r2 = r2_score(self.output, pred)
          r2_test = r2_score(self.test_output, test_pred)
          r2_val = r2_score(self.val_output, val_pred)
          r2_vt = r2_score(self.vt_output, vt_pred)
          r2_sup = r2_score(self.sup_output, sup_pred)

          mse = mean_squared_error(self.output, pred)
          mse_test = mean_squared_error(self.test_output, test_pred)
          mse_val = mean_squared_error(self.val_output, val_pred)
          mse_vt = mean_squared_error(self.vt_output, vt_pred)
          mse_sup = mean_squared_error(self.sup_output, sup_pred)

          metrics = {
                          'r2': r2,
                          'r2_sup': r2_sup,
                          'r2_test': r2_test,
                          'r2_val': r2_val,
                          'r2_vt': r2_vt,
                          'mse': mse,
                          'mse_sup': mse_sup,
                          'mse_test': mse_test,
                          'mse_val': mse_val,
                          'mse_vt': mse_vt
                          }

          return metrics


    def plot_results(self):
      fig = plt.figure(figsize=(18, 6))
      ax0 = fig.add_subplot(1, 3, 1, projection='3d')
      ax2 = fig.add_subplot(1, 3, 2, projection='3d')
      ax1 = fig.add_subplot(1, 3, 3)

      ax0.set_title('Superficie Fit')
      ax0.scatter(self.sup_input[:, 0], self.sup_input[:, 1], self.sup_prediction, c='r', marker='s', label="lm")
      ax0.scatter(self.sup_input[:, 0], self.sup_input[:, 1], self.sup_output, c='b', marker='o', label="reference")
      ax0.legend()

      ax2.set_title('Teste Fit')
      ax2.scatter(self.test_input[:, 0], self.test_input[:, 1], self.test_prediction, c='r', marker='s', label="lm")
      ax2.scatter(self.test_input[:, 0], self.test_input[:, 1], self.test_output, c='b', marker='o', label="reference")
      ax2.legend()

      ax1.plot(self.results.history['loss'], label='Erro Treino')
      ax1.plot(self.results.history['val_loss'], label='Erro validação')
      ax1.set_title('Histórico de Treinamento')
      ax1.set_ylabel('Função de Custo')
      ax1.set_xlabel('Épocas de Treinamento')
      ax1.legend(['Erro Treino', 'Erro validação'])

      return(fig)
# Out:
# 2024-01-30 00:33:40.938254: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-30 00:33:40.970901: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-30 00:33:40.970946: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-30 00:33:40.972186: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-30 00:33:40.978165: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-30 00:33:40.979094: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-30 00:33:41.887404: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from keras import saving
from keras import models
import pickle

class Tester:
  def __init__(self, run_times=500, dataset_run_times=10):
    self.run_times = run_times
    self.better_metrics = {}
    self.dataset_run_times = dataset_run_times
    self.input_25, self.output_25 = split_df(df_25)
    self.input_1000, self.output_1000 = split_df(df_1000)

  def PrepareTraining(self):
    trainer = TrainWithSmallDataset()
    trainer.split_dataset(self.input_25, self.output_25, self.input_1000, self.output_1000)
    return (trainer)

  def Train(self, trainer, epochs=1000):
    trainer.create_model()
    trainer.train_using_lm(trainer.train_dataset, epochs=epochs)
    return(trainer.get_metrics(), trainer.lm_model)

  def SaveModelWeights(self, model, fileName):
    path = f"../models/{fileName}.keras"
    open(path,'w').close()
    model.save_weights(path)
  
  def SaveFigs(self, trainer, fileName):
    path = f"../results/{fileName}.png" 
    open(path,'w').close()
    figure = trainer.plot_results()
    figure.savefig(path)
    plt.close(figure)

  def SaveDataset(self, trainer, fileName):
    path = f"../dataset/{fileName}.pkl" 
    with open(path, 'wb') as f:
      pickle.dump((trainer._train, trainer._vt, trainer._val, trainer._test), f)
  
  def LoadDataset(self, fileName, trainer=None):
    path = f"../dataset/{fileName}.pkl" 
    with open(path, 'rb') as f:
      _train, _vt, _val, _test = pickle.load(f)
    # trainer._train, trainer._vt, trainer._val, trainer._test = train, vt, val, test
    print(_train, _vt, _val, _test)

  # brief: for each dataset
  def Loop(self, sort_by, model_boundarie):
    better_model = 0

    for j in range(self.dataset_run_times):
      trainer = self.PrepareTraining() # split dataset
      self.SaveDataset(trainer, f"dataset_{j}")

      for i in range(self.run_times):
        print (f"+++++++++++ Dataset [{j + 1}] | {i + 1} ++++++++++++++++++")
        metrics, model = self.Train(trainer)
        if (metrics[sort_by] <= model_boundarie): # should be >= to acsending metrics
          fileName = f"model_{j}_{better_model}"
          self.SaveModelWeights(model, fileName)
          self.SaveFigs(trainer, fileName)
          self.better_metrics[fileName] = metrics
          better_model += 1
              

  def DisplayBetterResults(self, sort_by):
    df = pd.DataFrame.from_dict(self.better_metrics)
    df = df.transpose()
    df = df.sort_values([sort_by])
    display(df)
    excel_path = '../results/metrics.xlsx'
    df.to_excel(excel_path, index=False)
    print(f"DataFrame salvo em {excel_path}")

# %% [markdown]
# # Treinando com 25 dados

# %%
tester = Tester(run_times=100, dataset_run_times=50)

# %%
tester.Loop(sort_by='mse_sup', model_boundarie=2.5)
# Out:
# +++++++++++ Dataset [1] | 1 ++++++++++++++++++
# Elapsed time:  0.7860809559997506
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 2 ++++++++++++++++++
# Elapsed time:  0.4029949099995065
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 3 ++++++++++++++++++
# Elapsed time:  0.41658827399987786
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 4 ++++++++++++++++++
# Elapsed time:  0.39494179600023926
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 5 ++++++++++++++++++
# Elapsed time:  0.3860529060002591
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [1] | 6 ++++++++++++++++++
# Elapsed time:  0.46335410099982255
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 7 ++++++++++++++++++
# Elapsed time:  0.4630441229992357
# Stopped at epoch:  9
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 8 ++++++++++++++++++
# Elapsed time:  0.38959253299981356
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 9 ++++++++++++++++++
# Elapsed time:  0.4312316039995494
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 10 ++++++++++++++++++
# Elapsed time:  0.38162787799956277
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 11 ++++++++++++++++++
# Elapsed time:  0.4341920509996271
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 12 ++++++++++++++++++
# Elapsed time:  0.3967220610002187
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 13 ++++++++++++++++++
# Elapsed time:  0.3926794360004351
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 14 ++++++++++++++++++
# Elapsed time:  0.44335412199961866
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 15 ++++++++++++++++++
# Elapsed time:  0.5621399720002955
# Stopped at epoch:  10
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 16 ++++++++++++++++++
# Elapsed time:  0.40487543899962475
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [1] | 17 ++++++++++++++++++
# Elapsed time:  0.4874933579994831
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 18 ++++++++++++++++++
# Elapsed time:  0.5593237849998332
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 19 ++++++++++++++++++
# Elapsed time:  0.4768054520000078
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 20 ++++++++++++++++++
# Elapsed time:  0.4667006110003058
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 21 ++++++++++++++++++
# Elapsed time:  0.7252691419998882
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [1] | 22 ++++++++++++++++++
# Elapsed time:  0.8017878270002257
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 23 ++++++++++++++++++
# Elapsed time:  0.5931111199997758
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 24 ++++++++++++++++++
# Elapsed time:  0.4944480320000366
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 25 ++++++++++++++++++
# Elapsed time:  0.4312568209998062
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [1] | 26 ++++++++++++++++++
# Elapsed time:  0.8733962369997244
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 27 ++++++++++++++++++
# Elapsed time:  0.5240553439998621
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [1] | 28 ++++++++++++++++++
# Elapsed time:  0.43536319699978776
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 29 ++++++++++++++++++
# Elapsed time:  0.47201033199962694
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 30 ++++++++++++++++++
# Elapsed time:  0.4486917459998949
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 31 ++++++++++++++++++
# Elapsed time:  0.47529756699987047
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [1] | 32 ++++++++++++++++++
# Elapsed time:  0.4395107090003876
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [1] | 33 ++++++++++++++++++
# Elapsed time:  0.8320607409996228
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [1] | 34 ++++++++++++++++++
# Elapsed time:  0.5648555389998364
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 35 ++++++++++++++++++
# Elapsed time:  0.8728772889999163
# Stopped at epoch:  15
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [1] | 36 ++++++++++++++++++
# Elapsed time:  0.5390427980000823
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 37 ++++++++++++++++++
# Elapsed time:  0.45507042099961836
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 38 ++++++++++++++++++
# Elapsed time:  0.46302149100029055
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [1] | 39 ++++++++++++++++++
# Elapsed time:  0.5025700320002215
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [1] | 40 ++++++++++++++++++
# Elapsed time:  0.41962867900019774
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 41 ++++++++++++++++++
# Elapsed time:  0.48550365600021905
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 42 ++++++++++++++++++
# Elapsed time:  0.4702849579998656
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [1] | 43 ++++++++++++++++++
# Elapsed time:  0.456579299000623
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 44 ++++++++++++++++++
# Elapsed time:  0.5345363980004549
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 45 ++++++++++++++++++
# Elapsed time:  0.5275964330003262
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 46 ++++++++++++++++++
# Elapsed time:  0.454804697000327
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 47 ++++++++++++++++++
# Elapsed time:  0.8303824389995498
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [1] | 48 ++++++++++++++++++
# Elapsed time:  0.5574211830007698
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 49 ++++++++++++++++++
# Elapsed time:  0.543966248000288
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 50 ++++++++++++++++++
# Elapsed time:  0.5453019030001087
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 51 ++++++++++++++++++
# Elapsed time:  0.6758544049998818
# Stopped at epoch:  10
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 52 ++++++++++++++++++
# Elapsed time:  0.4242234240000471
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [1] | 53 ++++++++++++++++++
# Elapsed time:  0.4454764749998503
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [1] | 54 ++++++++++++++++++
# Elapsed time:  0.49010661600004823
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [1] | 55 ++++++++++++++++++
# Elapsed time:  0.8461476250004125
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 56 ++++++++++++++++++
# Elapsed time:  0.5246485820007365
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 57 ++++++++++++++++++
# Elapsed time:  0.4676587980002296
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 58 ++++++++++++++++++
# Elapsed time:  0.5805009929999869
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 59 ++++++++++++++++++
# Elapsed time:  0.45911009300016303
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 60 ++++++++++++++++++
# Elapsed time:  0.8090754380000362
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 61 ++++++++++++++++++
# Elapsed time:  0.44832426799985114
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [1] | 62 ++++++++++++++++++
# Elapsed time:  0.44621476299926144
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 63 ++++++++++++++++++
# Elapsed time:  0.5075286460005373
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 64 ++++++++++++++++++
# Elapsed time:  0.4585933660000592
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 65 ++++++++++++++++++
# Elapsed time:  0.5080626520002625
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [1] | 66 ++++++++++++++++++
# Elapsed time:  0.454263876999903
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 67 ++++++++++++++++++
# Elapsed time:  0.4644229479999922
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 68 ++++++++++++++++++
# Elapsed time:  0.5461425399998916
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 69 ++++++++++++++++++
# Elapsed time:  0.5905050169994865
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [1] | 70 ++++++++++++++++++
# Elapsed time:  0.4919900229997438
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 71 ++++++++++++++++++
# Elapsed time:  0.6110475599998608
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 72 ++++++++++++++++++
# Elapsed time:  0.5572606129999258
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 73 ++++++++++++++++++
# Elapsed time:  0.5038666619993819
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 74 ++++++++++++++++++
# Elapsed time:  0.564447009000105
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 75 ++++++++++++++++++
# Elapsed time:  0.5454276689997641
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 76 ++++++++++++++++++
# Elapsed time:  0.5352890829999524
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 77 ++++++++++++++++++
# Elapsed time:  0.9247042269998929
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 78 ++++++++++++++++++
# Elapsed time:  0.539726605999931
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 79 ++++++++++++++++++
# Elapsed time:  0.8085699059993203
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [1] | 80 ++++++++++++++++++
# Elapsed time:  0.6550777459997335
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 81 ++++++++++++++++++
# Elapsed time:  0.5194315630005804
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 82 ++++++++++++++++++
# Elapsed time:  0.8164360280006804
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 83 ++++++++++++++++++
# Elapsed time:  0.4777573080000366
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 84 ++++++++++++++++++
# Elapsed time:  0.5524629289993754
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 85 ++++++++++++++++++
# Elapsed time:  0.5372260880003523
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 86 ++++++++++++++++++
# Elapsed time:  0.5566205389995957
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 87 ++++++++++++++++++
# Elapsed time:  0.5774133309996614
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 24ms/step
# +++++++++++ Dataset [1] | 88 ++++++++++++++++++
# Elapsed time:  0.5457208239995452
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 89 ++++++++++++++++++
# Elapsed time:  0.8720048980003412
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 90 ++++++++++++++++++
# Elapsed time:  0.46889037799974176
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 91 ++++++++++++++++++
# Elapsed time:  0.5508681220007929
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [1] | 92 ++++++++++++++++++
# Elapsed time:  0.45798866899986024
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 93 ++++++++++++++++++
# Elapsed time:  0.5512882559996797
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 94 ++++++++++++++++++
# Elapsed time:  0.5029152470006011
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 95 ++++++++++++++++++
# Elapsed time:  0.733586646000731
# Stopped at epoch:  12
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 96 ++++++++++++++++++
# Elapsed time:  0.6290781150000839
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 97 ++++++++++++++++++
# Elapsed time:  0.5583188789996711
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [1] | 98 ++++++++++++++++++
# Elapsed time:  0.49448778399982984
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 99 ++++++++++++++++++
# Elapsed time:  0.9068330300005982
# Stopped at epoch:  9
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [1] | 100 ++++++++++++++++++
# Elapsed time:  0.5390581969995765
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [2] | 1 ++++++++++++++++++
# Elapsed time:  2.2351809820002018
# Stopped at epoch:  58
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 2 ++++++++++++++++++
# Elapsed time:  0.9042911440001262
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [2] | 3 ++++++++++++++++++
# Elapsed time:  0.5218379170000844
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [2] | 4 ++++++++++++++++++
# Elapsed time:  0.4416627230002632
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 5 ++++++++++++++++++
# Elapsed time:  0.5148052979993736
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 6 ++++++++++++++++++
# Elapsed time:  1.5754266720005035
# Stopped at epoch:  39
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [2] | 7 ++++++++++++++++++
# Elapsed time:  2.827375883000059
# Stopped at epoch:  75
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 8 ++++++++++++++++++
# Elapsed time:  1.0217132879997735
# Stopped at epoch:  14
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# +++++++++++ Dataset [2] | 9 ++++++++++++++++++
# Elapsed time:  1.8662958119994073
# Stopped at epoch:  48
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [2] | 10 ++++++++++++++++++
# Elapsed time:  0.5361767499998678
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [2] | 11 ++++++++++++++++++
# Elapsed time:  3.015135194999857
# Stopped at epoch:  74
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 12 ++++++++++++++++++
# Elapsed time:  0.5040828350001902
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 13 ++++++++++++++++++
# Elapsed time:  3.501274989000194
# Stopped at epoch:  91
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [2] | 14 ++++++++++++++++++
# Elapsed time:  0.44614348000050086
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 15 ++++++++++++++++++
# Elapsed time:  0.5336099790001754
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# +++++++++++ Dataset [2] | 16 ++++++++++++++++++
# Elapsed time:  0.48869604599985905
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [2] | 17 ++++++++++++++++++
# Elapsed time:  2.382614766000188
# Stopped at epoch:  57
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [2] | 18 ++++++++++++++++++
# Elapsed time:  0.46514815099999396
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 19 ++++++++++++++++++
# Elapsed time:  0.5090661849999378
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 20 ++++++++++++++++++
# Elapsed time:  1.2924834049999845
# Stopped at epoch:  28
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 21 ++++++++++++++++++
# Elapsed time:  0.47696877699945617
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 22 ++++++++++++++++++
# Elapsed time:  1.5288588710000113
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [2] | 23 ++++++++++++++++++
# Elapsed time:  0.5985663630008276
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [2] | 24 ++++++++++++++++++
# Elapsed time:  0.5303659759993025
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [2] | 25 ++++++++++++++++++
# Elapsed time:  0.6865172079997137
# Stopped at epoch:  10
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [2] | 26 ++++++++++++++++++
# Elapsed time:  0.4996693570001298
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 27 ++++++++++++++++++
# Elapsed time:  0.8557320049994814
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [2] | 28 ++++++++++++++++++
# Elapsed time:  0.8172647029996369
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [2] | 29 ++++++++++++++++++
# Elapsed time:  1.255837450999934
# Stopped at epoch:  28
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 30 ++++++++++++++++++
# Elapsed time:  2.3207378879997123
# Stopped at epoch:  66
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 31 ++++++++++++++++++
# Elapsed time:  2.3853173010002138
# Stopped at epoch:  57
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 32 ++++++++++++++++++
# Elapsed time:  0.6147387190003428
# Stopped at epoch:  9
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# ...
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 51ms/step
# +++++++++++ Dataset [29] | 23 ++++++++++++++++++
# Elapsed time:  3.4955751189991133
# Stopped at epoch:  85
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [29] | 24 ++++++++++++++++++
# Elapsed time:  7.544216824999239
# Stopped at epoch:  200
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# +++++++++++ Dataset [29] | 25 ++++++++++++++++++
# Elapsed time:  0.8410702100009075
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [29] | 26 ++++++++++++++++++
# Elapsed time:  6.484354723001161
# Stopped at epoch:  173
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [29] | 27 ++++++++++++++++++
# Elapsed time:  4.424084116999438
# Stopped at epoch:  107
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [29] | 28 ++++++++++++++++++
# Elapsed time:  2.1546197019997635
# Stopped at epoch:  53
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [29] | 29 ++++++++++++++++++
# Elapsed time:  1.7749882719999732
# Stopped at epoch:  39
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [29] | 30 ++++++++++++++++++
# Elapsed time:  5.401076873999045
# Stopped at epoch:  135
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# +++++++++++ Dataset [29] | 31 ++++++++++++++++++
# Elapsed time:  1.406158724999841
# Stopped at epoch:  30
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [29] | 32 ++++++++++++++++++
# Elapsed time:  2.3487558150009136
# Stopped at epoch:  53
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [29] | 33 ++++++++++++++++++
# Elapsed time:  3.741887563999626
# Stopped at epoch:  102
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [29] | 34 ++++++++++++++++++
# Elapsed time:  8.639596696999433
# Stopped at epoch:  245
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [29] | 35 ++++++++++++++++++
# Elapsed time:  6.589800886000376
# Stopped at epoch:  189
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [29] | 36 ++++++++++++++++++
# Elapsed time:  7.135732820999692
# Stopped at epoch:  192
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [29] | 37 ++++++++++++++++++
# Elapsed time:  4.523673276000409
# Stopped at epoch:  119
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [29] | 38 ++++++++++++++++++
# Elapsed time:  5.2579015379997145
# Stopped at epoch:  150
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# +++++++++++ Dataset [29] | 39 ++++++++++++++++++
# Elapsed time:  0.8374744270004157
# Stopped at epoch:  11
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [29] | 40 ++++++++++++++++++
# Elapsed time:  4.839351123999222
# Stopped at epoch:  126
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [29] | 41 ++++++++++++++++++
# Elapsed time:  3.889252510998631
# Stopped at epoch:  98
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [29] | 42 ++++++++++++++++++
# Elapsed time:  5.261582310000449
# Stopped at epoch:  148
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [29] | 43 ++++++++++++++++++
# Elapsed time:  5.343548552998982
# Stopped at epoch:  144
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [29] | 44 ++++++++++++++++++
# Elapsed time:  0.855933721000838
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# +++++++++++ Dataset [29] | 45 ++++++++++++++++++
# Elapsed time:  5.462806281999292
# Stopped at epoch:  136
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# +++++++++++ Dataset [29] | 46 ++++++++++++++++++
# Elapsed time:  6.242539654998836
# Stopped at epoch:  166
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [29] | 47 ++++++++++++++++++
# Elapsed time:  4.913295615000607
# Stopped at epoch:  122
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [29] | 48 ++++++++++++++++++
# Elapsed time:  0.8374706889990193
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# +++++++++++ Dataset [29] | 49 ++++++++++++++++++
# Elapsed time:  3.517481281000073
# Stopped at epoch:  90
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# +++++++++++ Dataset [29] | 50 ++++++++++++++++++
# Elapsed time:  5.370245566000449
# Stopped at epoch:  137
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [29] | 51 ++++++++++++++++++
# Elapsed time:  4.888917470998422
# Stopped at epoch:  132
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# +++++++++++ Dataset [29] | 52 ++++++++++++++++++
# Elapsed time:  5.028169092000098
# Stopped at epoch:  140
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [29] | 53 ++++++++++++++++++
# Elapsed time:  0.9851063610003621
# Stopped at epoch:  13
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# +++++++++++ Dataset [29] | 54 ++++++++++++++++++
# Elapsed time:  6.7683683579998615
# Stopped at epoch:  195
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [29] | 55 ++++++++++++++++++
# Elapsed time:  0.7112663819989393
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [29] | 56 ++++++++++++++++++
# Elapsed time:  2.78335833500023
# Stopped at epoch:  62
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [29] | 57 ++++++++++++++++++
# Elapsed time:  5.730289414999788
# Stopped at epoch:  155
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [29] | 58 ++++++++++++++++++
# Elapsed time:  2.1149172940004064
# Stopped at epoch:  47
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [29] | 59 ++++++++++++++++++
# Elapsed time:  3.2955165929997747
# Stopped at epoch:  95
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [29] | 60 ++++++++++++++++++
# Elapsed time:  4.609431318998759
# Stopped at epoch:  117
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [29] | 61 ++++++++++++++++++
# Elapsed time:  4.727517369999987
# Stopped at epoch:  131
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [29] | 62 ++++++++++++++++++
# Elapsed time:  1.929413634001321
# Stopped at epoch:  48
# 32/32 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [29] | 63 ++++++++++++++++++
# Elapsed time:  3.4477713010001025
# Stopped at epoch:  88
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [29] | 64 ++++++++++++++++++
# Elapsed time:  7.869403472999693
# Stopped at epoch:  211
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [29] | 65 ++++++++++++++++++
# Elapsed time:  5.149515120001524
# Stopped at epoch:  137
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [29] | 66 ++++++++++++++++++

# %%
tester.DisplayBetterResults('mse_sup')
# Out:
#                    r2    r2_sup   r2_test    r2_val     r2_vt       mse  \
# model_12_3   0.912817  0.709965  0.789034  0.787231  0.809304  0.365887
# model_86_20  0.896575  0.689825  0.958560  0.611721  0.707947  0.434054
# model_32_12  0.843180  0.686478  0.713144  0.766650  0.768147  0.658139
# model_94_21  0.861332  0.671307  0.703001  0.590693  0.607494  0.581959
# model_38_16  0.856884  0.671065  0.775598  0.470174  0.619945  0.600628
# model_32_11  0.817672  0.669968  0.733347  0.718752  0.730434  0.765193
# model_12_4   0.882245  0.656542  0.500607  0.835977  0.742433  0.494193
# model_7_0    0.879245  0.654805  0.733049  0.669689  0.718666  0.506783
# model_7_1    0.863382  0.644982  0.868800  0.665572  0.733781  0.573355
# model_16_6   0.731483  0.643319  0.395428  0.691814  0.590159  1.126908
# model_16_7   0.772527  0.643172  0.516262  0.712890  0.654454  0.954657
# model_19_10  0.843713  0.641879  0.600155  0.693700  0.686745  0.655904
# model_71_19  0.820692  0.641853 -0.088750  0.757573  0.535755  0.752519
# model_7_2    0.869456  0.639689  0.756498  0.661719  0.715880  0.547865
# model_16_8   0.734590  0.637043  0.421839  0.675009  0.594902  1.113868
# model_58_18  0.876235  0.636924  0.340697  0.464901  0.685196  0.519417
# model_43_17  0.851557  0.634899 -0.699639  0.783944  0.657581  0.622982
# model_12_5   0.854511  0.631787  0.592652  0.711769  0.701762  0.610586
# model_37_13  0.763958  0.631113  0.066096  0.620888  0.585303  0.990618
# model_17_9   0.812752  0.629184 -0.065028  0.616312  0.461854  0.785838
# model_37_14  0.793996  0.628075  0.141399  0.717748  0.646710  0.864553
# model_38_15  0.824549  0.627217  0.685831  0.467590  0.595941  0.736328
#
#               mse_sup  mse_test   mse_val    mse_vt
# model_12_3   1.939464  0.830575  1.456219  1.143397
# model_86_20  2.074143  0.043276  1.481779  0.762527
# model_32_12  2.096526  0.635646  3.477723  2.056684
# model_94_21  2.197973  0.217619  2.837029  1.527324
# model_38_16  2.199590  0.544178  3.145496  1.844837
# model_32_11  2.206926  0.590878  4.191576  2.391227
# model_12_4   2.296708  1.966113  1.122593  1.544353
# model_7_0    2.308319  0.271344  1.864515  1.067930
# model_7_1    2.374004  0.133359  1.887753  1.010556
# model_16_6   2.385126  4.740208  2.302968  3.521588
# model_16_7   2.386110  3.792796  2.145475  2.969136
# model_19_10  2.394758  0.816390  2.192847  1.504619
# model_71_19  2.394929  2.232752  1.399680  1.816216
# model_7_2    2.409400  0.247510  1.909505  1.078508
# model_16_8   2.427094  4.533126  2.428547  3.480837
# model_58_18  2.427893  0.504146  2.254568  1.379357
# model_43_17  2.441434  1.601725  1.435710  1.518717
# model_12_5   2.462242  1.603731  1.972692  1.788212
# model_37_13  2.466752  3.803373  2.387950  3.095661
# model_17_9   2.479648  1.960926  1.992244  1.976585
# model_37_14  2.487064  3.496697  1.777848  2.637272
# model_38_15  2.492805  0.761866  3.160838  1.961352
# DataFrame salvo em ../results/metrics.xlsx
