# %%
import os

os.chdir("./content")

lm_dir = "tf-levenberg-marquardt"
if not os.path.exists(lm_dir):
  # !git clone https://github.com/fabiodimarco/$lm_dir

os.chdir(lm_dir)

# %%
# !pip install --upgrade pip
# !pip install tensorflow 
# !pip install openpyxl
# Out:
# Requirement already satisfied: pip in /usr/local/python/3.10.13/lib/python3.10/site-packages (23.3.2)
# Requirement already satisfied: tensorflow in /usr/local/python/3.10.13/lib/python3.10/site-packages (2.15.0.post1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (1.26.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (0.35.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.26.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/codespace/.local/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)
# Requirement already satisfied: openpyxl in /usr/local/python/3.10.13/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/python/3.10.13/lib/python3.10/site-packages (from openpyxl) (1.1.0)

# %%
import numpy as np
import pandas as pd
from scipy.stats import zscore
from sklearn.preprocessing import MaxAbsScaler

def peaks(grid):
    x = np.linspace(-2, 2, grid)
    y = np.linspace(-2, 2, grid)
    x, y = np.meshgrid(x, y)
    z = 3*(1-x)**2 * np.exp(-(x**2) - (y+1)**2) - 10*(x/5 - x**3 - y**5) * np.exp(-x**2 - y**2) - 1/3 * np.exp(-(x+1)**2 - y**2)
    return x, y, z

def create_dataframe(grid):
   x, y, z = peaks(grid)
   data = {'X': x.flatten(), 'Y': y.flatten(), 'Z': z.flatten()}
   df = pd.DataFrame(data)
   return df

# %%
df_25 = create_dataframe(grid=5)
df_1000 = create_dataframe(grid=32)

# %%
def split_df(df):
    # df = df.sample(frac=1).reset_index(drop=True)  # Randomiza as linhas
    _input = np.vstack([df['X'], df['Y']]).T
    _output = np.array(df['Z'])
    return (_input, _output)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import levenberg_marquardt as lm
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
from sklearn.metrics import r2_score, mean_squared_error
from keras import regularizers
from keras import initializers

class TrainWithSmallDataset:
    def __init__(self, batch_size=1000, store=25):
        self.batch_size = batch_size
        self.betters = []
        self.store = store

    def create_dataset(self, input, output):
      input = tf.expand_dims(tf.cast(input, tf.float32), axis=-1)
      output = tf.expand_dims(tf.cast(output, tf.float32), axis=-1)

      dataset = tf.data.Dataset.from_tensor_slices((input, output))
      dataset = dataset.shuffle(len(input))
      dataset = dataset.batch(self.batch_size).cache()
      dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
      return (dataset, input, output)


    def split_dataset(self, input, output, sup_input, sup_output):

      input_train, input_vt, output_train, output_vt = train_test_split(input, output, test_size=0.3, shuffle = True)
      input_val, input_test, output_val, output_test = train_test_split(input_vt, output_vt, test_size=0.5, shuffle = True)

      self.train_dataset, self.train_input, self.train_output = self.create_dataset(input_train, output_train)
      self.val_dataset, self.val_input, self.val_output = self.create_dataset(input_val, output_val)
      self.test_dataset, self.test_input, self.test_output = self.create_dataset(input_test, output_test)
      self.vt_dataset, self.vt_input, self.vt_output = self.create_dataset(input_vt, output_vt)
      self.sup_dataset, self.sup_input, self.sup_output = self.create_dataset(sup_input, sup_output)
      self.dataset, self.input, self.output = self.create_dataset(input, output)

      self._train = (input_train, output_train)
      self._vt = (input_vt, output_vt)
      self._val = (input_val, output_val)
      self._test = (input_test, output_test)

    def create_model(self, input_size=2, sumary=False):
      regularizer = regularizers.L2(0.2)
      initializer = initializers.RandomUniform(minval=-0.5, maxval=0.5, seed=np.random.randint(1, 10000))

      self.model = tf.keras.Sequential([
          tf.keras.layers.Dense(30,
                                activation='tanh',
                                input_shape=(input_size,),
                                kernel_regularizer=regularizer,
                                kernel_initializer=initializer,
                                ),
          tf.keras.layers.Dense(16,
                                activation='tanh',
                                kernel_regularizer=regularizer,
                                kernel_initializer=initializer,
                                ),
          tf.keras.layers.Dense(1,
                                activation='linear',
                                kernel_regularizer=regularizer,
                                kernel_initializer=initializer,
        )])

      if (sumary == True):
        self.model.summary()

      self.model.compile(
          optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
          loss=tf.keras.losses.MeanSquaredError())

      self.lm_model = lm.ModelWrapper(
          tf.keras.models.clone_model(self.model))

      self.lm_model.compile(
          optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
          loss=lm.MeanSquaredError())

    def train_using_lm(self, train_dataset, epochs=1000):
      early_stopping_monitor = EarlyStopping(monitor='val_loss',
                                              patience=6,
                                              restore_best_weights=True)

      t2_start = time.perf_counter()
      self.results = self.lm_model.fit(train_dataset,
                                            epochs=epochs,
                                            validation_data=self.val_dataset,
                                            callbacks=[early_stopping_monitor],
                                            verbose=0)
      t2_stop = time.perf_counter()
      print("Elapsed time: ", t2_stop - t2_start)
      print ("Stopped at epoch: ", early_stopping_monitor.stopped_epoch)

    def get_metrics(self):
          self.sup_prediction = self.lm_model.predict(self.sup_input)
          self.test_prediction = self.lm_model.predict(self.test_input)

          pred = self.lm_model.predict(self.input).flatten()
          test_pred = self.test_prediction.flatten()
          val_pred = self.lm_model.predict(self.val_input).flatten()
          vt_pred = self.lm_model.predict(self.vt_input).flatten()
          sup_pred = self.sup_prediction.flatten()

          r2 = r2_score(self.output, pred)
          r2_test = r2_score(self.test_output, test_pred)
          r2_val = r2_score(self.val_output, val_pred)
          r2_vt = r2_score(self.vt_output, vt_pred)
          r2_sup = r2_score(self.sup_output, sup_pred)

          mse = mean_squared_error(self.output, pred)
          mse_test = mean_squared_error(self.test_output, test_pred)
          mse_val = mean_squared_error(self.val_output, val_pred)
          mse_vt = mean_squared_error(self.vt_output, vt_pred)
          mse_sup = mean_squared_error(self.sup_output, sup_pred)

          metrics = {
                          'r2': r2,
                          'r2_sup': r2_sup,
                          'r2_test': r2_test,
                          'r2_val': r2_val,
                          'r2_vt': r2_vt,
                          'mse': mse,
                          'mse_sup': mse_sup,
                          'mse_test': mse_test,
                          'mse_val': mse_val,
                          'mse_vt': mse_vt
                          }

          return metrics


    def plot_results(self):
      fig = plt.figure(figsize=(18, 6))
      ax0 = fig.add_subplot(1, 3, 1, projection='3d')
      ax2 = fig.add_subplot(1, 3, 2, projection='3d')
      ax1 = fig.add_subplot(1, 3, 3)

      ax0.set_title('Superficie Fit')
      ax0.scatter(self.sup_input[:, 0], self.sup_input[:, 1], self.sup_prediction, c='r', marker='s', label="lm")
      ax0.scatter(self.sup_input[:, 0], self.sup_input[:, 1], self.sup_output, c='b', marker='o', label="reference")
      ax0.legend()

      ax2.set_title('Teste Fit')
      ax2.scatter(self.test_input[:, 0], self.test_input[:, 1], self.test_prediction, c='r', marker='s', label="lm")
      ax2.scatter(self.test_input[:, 0], self.test_input[:, 1], self.test_output, c='b', marker='o', label="reference")
      ax2.legend()

      ax1.plot(self.results.history['loss'], label='Erro Treino')
      ax1.plot(self.results.history['val_loss'], label='Erro validação')
      ax1.set_title('Histórico de Treinamento')
      ax1.set_ylabel('Função de Custo')
      ax1.set_xlabel('Épocas de Treinamento')
      ax1.legend(['Erro Treino', 'Erro validação'])

      return(fig)
# Out:
# 2024-01-30 01:53:05.400182: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-30 01:53:05.442916: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-30 01:53:05.442961: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-30 01:53:05.444100: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-30 01:53:05.449922: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-30 01:53:05.450422: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-30 01:53:06.527633: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from keras import saving
from keras import models
import pickle

class Tester:
  def __init__(self, run_times=500, dataset_run_times=10):
    self.run_times = run_times
    self.better_metrics = {}
    self.dataset_run_times = dataset_run_times
    self.input_25, self.output_25 = split_df(df_25)
    self.input_1000, self.output_1000 = split_df(df_1000)

  def PrepareTraining(self):
    trainer = TrainWithSmallDataset()
    trainer.split_dataset(self.input_25, self.output_25, self.input_1000, self.output_1000)
    return (trainer)

  def Train(self, trainer, epochs=1000):
    trainer.create_model()
    trainer.train_using_lm(trainer.train_dataset, epochs=epochs)
    return(trainer.get_metrics(), trainer.lm_model)

  def SaveModelWeights(self, model, fileName):
    path = f"../models/{fileName}.keras"
    open(path,'w').close()
    model.save_weights(path)
  
  def SaveFigs(self, trainer, fileName):
    path = f"../results/{fileName}.png" 
    open(path,'w').close()
    figure = trainer.plot_results()
    figure.savefig(path)
    plt.close(figure)

  def SaveDataset(self, trainer, fileName):
    path = f"../dataset/{fileName}.pkl" 
    with open(path, 'wb') as f:
      pickle.dump((trainer._train, trainer._vt, trainer._val, trainer._test), f)
  
  def LoadDataset(self, fileName, trainer=None):
    path = f"../dataset/{fileName}.pkl" 
    with open(path, 'rb') as f:
      _train, _vt, _val, _test = pickle.load(f)
    # trainer._train, trainer._vt, trainer._val, trainer._test = train, vt, val, test
    print(_train, _vt, _val, _test)

  # brief: for each dataset
  def Loop(self, sort_by, boundarie):
    better_model = 0

    for j in range(self.dataset_run_times):
      trainer = self.PrepareTraining() # split dataset
      self.SaveDataset(trainer, f"dataset_{j}")

      for i in range(self.run_times):
        print (f"+++++++++++ Dataset [{j + 1}] | {i + 1} ++++++++++++++++++")
        metrics, model = self.Train(trainer)
        if (metrics[sort_by] <= boundarie): # should be >= to acsending metrics
          fileName = f"model_{j}_{better_model}"
          self.SaveModelWeights(model, fileName)
          self.SaveFigs(trainer, fileName)
          self.better_metrics[fileName] = metrics
          better_model += 1
              

  def DisplayBetterResults(self, sort_by):
    df = pd.DataFrame.from_dict(self.better_metrics, orient='index')
    df = df.sort_values([sort_by])
    display(df)
    excel_path = '../results/metrics.xlsx'
    df.to_excel(excel_path, index=True)
    print(f"DataFrame salvo em {excel_path}")

# %% [markdown]
# # Treinando com 25 dados

# %%
tester = Tester(run_times=100, dataset_run_times=50)

# %%
tester.Loop(sort_by='mse_sup', boundarie=2.5)
# Out:
# +++++++++++ Dataset [1] | 1 ++++++++++++++++++
# Elapsed time:  2.224735014999169
# Stopped at epoch:  50
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 2 ++++++++++++++++++
# Elapsed time:  1.0249552269997366
# Stopped at epoch:  26
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 3 ++++++++++++++++++
# Elapsed time:  2.267568207000295
# Stopped at epoch:  61
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 4 ++++++++++++++++++
# Elapsed time:  0.828067087000818
# Stopped at epoch:  16
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [1] | 5 ++++++++++++++++++
# Elapsed time:  1.7145069609996426
# Stopped at epoch:  45
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 6 ++++++++++++++++++
# Elapsed time:  2.694056176000231
# Stopped at epoch:  69
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 7 ++++++++++++++++++
# Elapsed time:  2.8773692100003245
# Stopped at epoch:  71
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [1] | 8 ++++++++++++++++++
# Elapsed time:  2.9313579509998817
# Stopped at epoch:  78
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 9 ++++++++++++++++++
# Elapsed time:  2.3993347060004453
# Stopped at epoch:  63
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 10 ++++++++++++++++++
# Elapsed time:  2.249724500999946
# Stopped at epoch:  60
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 11 ++++++++++++++++++
# Elapsed time:  2.1217358140002034
# Stopped at epoch:  56
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [1] | 12 ++++++++++++++++++
# Elapsed time:  2.1477744370004075
# Stopped at epoch:  62
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 13 ++++++++++++++++++
# Elapsed time:  1.922070217999135
# Stopped at epoch:  48
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 14 ++++++++++++++++++
# Elapsed time:  1.1502535449999414
# Stopped at epoch:  27
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 15 ++++++++++++++++++
# Elapsed time:  4.158708191000187
# Stopped at epoch:  113
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 16 ++++++++++++++++++
# Elapsed time:  1.8566126669993537
# Stopped at epoch:  54
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 17 ++++++++++++++++++
# Elapsed time:  2.8470392180006456
# Stopped at epoch:  77
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 18 ++++++++++++++++++
# Elapsed time:  1.9015308910002204
# Stopped at epoch:  44
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 19 ++++++++++++++++++
# Elapsed time:  3.898068164000506
# Stopped at epoch:  115
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 20 ++++++++++++++++++
# Elapsed time:  2.223749114999009
# Stopped at epoch:  54
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 21 ++++++++++++++++++
# Elapsed time:  0.5142896550005389
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 22 ++++++++++++++++++
# Elapsed time:  2.1950314929999877
# Stopped at epoch:  57
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 23 ++++++++++++++++++
# Elapsed time:  1.4855538699994213
# Stopped at epoch:  40
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 24 ++++++++++++++++++
# Elapsed time:  1.9847961569994368
# Stopped at epoch:  49
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 25 ++++++++++++++++++
# Elapsed time:  1.2739597869986028
# Stopped at epoch:  33
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 26 ++++++++++++++++++
# Elapsed time:  2.752799814001264
# Stopped at epoch:  68
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 27 ++++++++++++++++++
# Elapsed time:  0.4653881909998745
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 28 ++++++++++++++++++
# Elapsed time:  0.8187146729997039
# Stopped at epoch:  14
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 29 ++++++++++++++++++
# Elapsed time:  0.831230551999397
# Stopped at epoch:  18
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 30 ++++++++++++++++++
# Elapsed time:  0.9632137329990655
# Stopped at epoch:  24
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# +++++++++++ Dataset [1] | 31 ++++++++++++++++++
# Elapsed time:  3.070309923001332
# Stopped at epoch:  71
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 32 ++++++++++++++++++
# Elapsed time:  2.658043887999156
# Stopped at epoch:  61
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 33 ++++++++++++++++++
# Elapsed time:  2.375200024998776
# Stopped at epoch:  61
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [1] | 34 ++++++++++++++++++
# Elapsed time:  1.5266593659998762
# Stopped at epoch:  38
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 35 ++++++++++++++++++
# Elapsed time:  0.6822818229993572
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 36 ++++++++++++++++++
# Elapsed time:  2.540388196999629
# Stopped at epoch:  65
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 37 ++++++++++++++++++
# Elapsed time:  2.462531606999619
# Stopped at epoch:  66
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 38 ++++++++++++++++++
# Elapsed time:  2.3507023399997706
# Stopped at epoch:  62
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 39 ++++++++++++++++++
# Elapsed time:  1.5776271180002368
# Stopped at epoch:  40
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 40 ++++++++++++++++++
# Elapsed time:  3.1722283300005074
# Stopped at epoch:  87
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 41 ++++++++++++++++++
# Elapsed time:  1.449768081000002
# Stopped at epoch:  34
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 42 ++++++++++++++++++
# Elapsed time:  2.7004231010014337
# Stopped at epoch:  77
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 43 ++++++++++++++++++
# Elapsed time:  2.260305118999895
# Stopped at epoch:  61
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 44 ++++++++++++++++++
# Elapsed time:  2.3629565329993056
# Stopped at epoch:  63
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 45 ++++++++++++++++++
# Elapsed time:  1.240784714000256
# Stopped at epoch:  27
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 46 ++++++++++++++++++
# Elapsed time:  0.467000698999982
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [1] | 47 ++++++++++++++++++
# Elapsed time:  2.595959385000242
# Stopped at epoch:  65
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 48 ++++++++++++++++++
# Elapsed time:  1.6546604249997472
# Stopped at epoch:  32
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 49 ++++++++++++++++++
# Elapsed time:  2.20928123900012
# Stopped at epoch:  55
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 50 ++++++++++++++++++
# Elapsed time:  1.0673083429992403
# Stopped at epoch:  24
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 51 ++++++++++++++++++
# Elapsed time:  0.5731143579996569
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 52 ++++++++++++++++++
# Elapsed time:  0.9345347259986738
# Stopped at epoch:  25
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# +++++++++++ Dataset [1] | 53 ++++++++++++++++++
# Elapsed time:  1.9045974450000358
# Stopped at epoch:  38
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 54 ++++++++++++++++++
# Elapsed time:  0.8770388360007928
# Stopped at epoch:  18
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 55 ++++++++++++++++++
# Elapsed time:  2.1607804630002647
# Stopped at epoch:  53
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# +++++++++++ Dataset [1] | 56 ++++++++++++++++++
# Elapsed time:  2.293747469999289
# Stopped at epoch:  63
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 57 ++++++++++++++++++
# Elapsed time:  2.1040337520007597
# Stopped at epoch:  54
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 58 ++++++++++++++++++
# Elapsed time:  1.3066333450005914
# Stopped at epoch:  29
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 59 ++++++++++++++++++
# Elapsed time:  3.887745807000101
# Stopped at epoch:  108
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 60 ++++++++++++++++++
# Elapsed time:  0.48841722600081994
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 61 ++++++++++++++++++
# Elapsed time:  0.7883485809998092
# Stopped at epoch:  18
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [1] | 62 ++++++++++++++++++
# Elapsed time:  2.069668056001319
# Stopped at epoch:  47
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 63 ++++++++++++++++++
# Elapsed time:  0.5535119069991197
# Stopped at epoch:  9
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 64 ++++++++++++++++++
# Elapsed time:  0.9950481960004254
# Stopped at epoch:  18
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 65 ++++++++++++++++++
# Elapsed time:  2.2514415650002775
# Stopped at epoch:  56
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 66 ++++++++++++++++++
# Elapsed time:  2.845213648999561
# Stopped at epoch:  78
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 67 ++++++++++++++++++
# Elapsed time:  2.840567228000509
# Stopped at epoch:  74
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 68 ++++++++++++++++++
# Elapsed time:  0.4538309660001687
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [1] | 69 ++++++++++++++++++
# Elapsed time:  1.8141881089995877
# Stopped at epoch:  48
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 70 ++++++++++++++++++
# Elapsed time:  1.3791341400010424
# Stopped at epoch:  24
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 71 ++++++++++++++++++
# Elapsed time:  0.6277895109997189
# Stopped at epoch:  9
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 72 ++++++++++++++++++
# Elapsed time:  2.500134411000545
# Stopped at epoch:  68
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [1] | 73 ++++++++++++++++++
# Elapsed time:  4.117695758999616
# Stopped at epoch:  111
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 74 ++++++++++++++++++
# Elapsed time:  0.5186175229991932
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 75 ++++++++++++++++++
# Elapsed time:  2.5935481329997856
# Stopped at epoch:  67
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 76 ++++++++++++++++++
# Elapsed time:  1.9482326890010881
# Stopped at epoch:  49
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 77 ++++++++++++++++++
# Elapsed time:  2.4990108750007494
# Stopped at epoch:  66
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 78 ++++++++++++++++++
# Elapsed time:  2.921983914999146
# Stopped at epoch:  83
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 79 ++++++++++++++++++
# Elapsed time:  1.9376446360001864
# Stopped at epoch:  41
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# +++++++++++ Dataset [1] | 80 ++++++++++++++++++
# Elapsed time:  2.7039257989999896
# Stopped at epoch:  72
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# +++++++++++ Dataset [1] | 81 ++++++++++++++++++
# Elapsed time:  2.6387964410005225
# Stopped at epoch:  76
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 82 ++++++++++++++++++
# Elapsed time:  3.054538203001357
# Stopped at epoch:  83
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 83 ++++++++++++++++++
# Elapsed time:  1.1928482100011024
# Stopped at epoch:  26
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [1] | 84 ++++++++++++++++++
# Elapsed time:  1.0769947829994635
# Stopped at epoch:  26
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# +++++++++++ Dataset [1] | 85 ++++++++++++++++++
# Elapsed time:  1.0531366689992865
# Stopped at epoch:  14
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 86 ++++++++++++++++++
# Elapsed time:  2.2896936950000963
# Stopped at epoch:  60
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 87 ++++++++++++++++++
# Elapsed time:  2.310125138999865
# Stopped at epoch:  64
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 88 ++++++++++++++++++
# Elapsed time:  0.9317983479995746
# Stopped at epoch:  18
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [1] | 89 ++++++++++++++++++
# Elapsed time:  0.7394181009985914
# Stopped at epoch:  10
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 90 ++++++++++++++++++
# Elapsed time:  3.5726384929985215
# Stopped at epoch:  88
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [1] | 91 ++++++++++++++++++
# Elapsed time:  1.8562644680005178
# Stopped at epoch:  47
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 92 ++++++++++++++++++
# Elapsed time:  2.286610547998862
# Stopped at epoch:  56
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [1] | 93 ++++++++++++++++++
# Elapsed time:  1.1353984550005407
# Stopped at epoch:  25
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 94 ++++++++++++++++++
# Elapsed time:  2.8443727390003914
# Stopped at epoch:  74
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [1] | 95 ++++++++++++++++++
# Elapsed time:  2.0265138849990763
# Stopped at epoch:  54
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 96 ++++++++++++++++++
# Elapsed time:  2.3319988399998692
# Stopped at epoch:  59
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 97 ++++++++++++++++++
# Elapsed time:  2.4223398249996535
# Stopped at epoch:  60
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 98 ++++++++++++++++++
# Elapsed time:  2.366876259999117
# Stopped at epoch:  65
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# +++++++++++ Dataset [1] | 99 ++++++++++++++++++
# Elapsed time:  0.538863293999384
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 100 ++++++++++++++++++
# Elapsed time:  0.9328855269995984
# Stopped at epoch:  14
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [2] | 1 ++++++++++++++++++
# Elapsed time:  0.536782058999961
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 2 ++++++++++++++++++
# Elapsed time:  0.937834723999913
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# +++++++++++ Dataset [2] | 3 ++++++++++++++++++
# Elapsed time:  0.8985064460011927
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 4 ++++++++++++++++++
# Elapsed time:  0.6235913110012916
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [2] | 5 ++++++++++++++++++
# Elapsed time:  0.6519957010004873
# Stopped at epoch:  9
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [2] | 6 ++++++++++++++++++
# Elapsed time:  0.528251187000933
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [2] | 7 ++++++++++++++++++
# Elapsed time:  0.5753680229991005
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [2] | 8 ++++++++++++++++++
# Elapsed time:  0.5809620229993016
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [2] | 9 ++++++++++++++++++
# Elapsed time:  0.42242476499995973
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 10 ++++++++++++++++++
# Elapsed time:  0.47032010599832574
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 11 ++++++++++++++++++
# Elapsed time:  0.5071412050001527
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 12 ++++++++++++++++++
# Elapsed time:  0.6851155610002024
# Stopped at epoch:  9
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 13 ++++++++++++++++++
# Elapsed time:  0.5294103390006057
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 14 ++++++++++++++++++
# Elapsed time:  0.4194623170005798
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 15 ++++++++++++++++++
# Elapsed time:  0.784423101998982
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [2] | 16 ++++++++++++++++++
# Elapsed time:  0.5020423740006663
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# +++++++++++ Dataset [2] | 17 ++++++++++++++++++
# Elapsed time:  0.6460268089995225
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 18 ++++++++++++++++++
# Elapsed time:  0.9006591950001166
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [2] | 19 ++++++++++++++++++
# Elapsed time:  0.4856126419999782
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 20 ++++++++++++++++++
# Elapsed time:  0.566416775000107
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 21 ++++++++++++++++++
# Elapsed time:  0.8096789739993255
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [2] | 22 ++++++++++++++++++
# Elapsed time:  0.5281230270011292
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [2] | 23 ++++++++++++++++++
# Elapsed time:  0.4679107389983983
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [2] | 24 ++++++++++++++++++
# Elapsed time:  0.5589748740003415
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [2] | 25 ++++++++++++++++++
# Elapsed time:  0.6403563670010044
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [2] | 26 ++++++++++++++++++
# Elapsed time:  1.153521856000225
# Stopped at epoch:  21
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [2] | 27 ++++++++++++++++++
# Elapsed time:  0.9347473220004758
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [2] | 28 ++++++++++++++++++
# Elapsed time:  0.8478218889995333
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# +++++++++++ Dataset [2] | 29 ++++++++++++++++++
# Elapsed time:  0.4194466860008106
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [2] | 30 ++++++++++++++++++
# Elapsed time:  0.5347448760003317
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [2] | 31 ++++++++++++++++++
# Elapsed time:  0.6059176449998631
# Stopped at epoch:  9
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [2] | 32 ++++++++++++++++++
# Elapsed time:  0.5353984970006422
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# ...
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# +++++++++++ Dataset [9] | 87 ++++++++++++++++++
# Elapsed time:  0.7134623340007238
# Stopped at epoch:  11
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [9] | 88 ++++++++++++++++++
# Elapsed time:  3.5478813240006275
# Stopped at epoch:  102
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [9] | 89 ++++++++++++++++++
# Elapsed time:  3.9617922569996153
# Stopped at epoch:  106
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [9] | 90 ++++++++++++++++++
# Elapsed time:  4.3291383480009245
# Stopped at epoch:  123
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [9] | 91 ++++++++++++++++++
# Elapsed time:  2.4383637640003144
# Stopped at epoch:  65
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [9] | 92 ++++++++++++++++++
# Elapsed time:  5.424373789001038
# Stopped at epoch:  151
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [9] | 93 ++++++++++++++++++
# Elapsed time:  6.390608952999173
# Stopped at epoch:  180
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [9] | 94 ++++++++++++++++++
# Elapsed time:  4.929664610001055
# Stopped at epoch:  146
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [9] | 95 ++++++++++++++++++
# Elapsed time:  5.071083363000071
# Stopped at epoch:  139
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [9] | 96 ++++++++++++++++++
# Elapsed time:  3.6210277339996537
# Stopped at epoch:  87
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [9] | 97 ++++++++++++++++++
# Elapsed time:  4.982842247000008
# Stopped at epoch:  125
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [9] | 98 ++++++++++++++++++
# Elapsed time:  3.782550676000028
# Stopped at epoch:  104
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [9] | 99 ++++++++++++++++++
# Elapsed time:  5.247621160000563
# Stopped at epoch:  144
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [9] | 100 ++++++++++++++++++
# Elapsed time:  4.216662848000851
# Stopped at epoch:  115
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [10] | 1 ++++++++++++++++++
# Elapsed time:  2.034316831999604
# Stopped at epoch:  49
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [10] | 2 ++++++++++++++++++
# Elapsed time:  3.2060609399995883
# Stopped at epoch:  85
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [10] | 3 ++++++++++++++++++
# Elapsed time:  3.027747226000429
# Stopped at epoch:  83
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [10] | 4 ++++++++++++++++++
# Elapsed time:  1.8597878259988647
# Stopped at epoch:  45
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [10] | 5 ++++++++++++++++++
# Elapsed time:  2.583521046999522
# Stopped at epoch:  62
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [10] | 6 ++++++++++++++++++
# Elapsed time:  1.903228348999619
# Stopped at epoch:  43
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# +++++++++++ Dataset [10] | 7 ++++++++++++++++++
# Elapsed time:  0.6017371929992805
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [10] | 8 ++++++++++++++++++
# Elapsed time:  1.5045128969995858
# Stopped at epoch:  33
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# +++++++++++ Dataset [10] | 9 ++++++++++++++++++
# Elapsed time:  2.3438348899999255
# Stopped at epoch:  59
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [10] | 10 ++++++++++++++++++
# Elapsed time:  3.511717563000275
# Stopped at epoch:  101
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# +++++++++++ Dataset [10] | 11 ++++++++++++++++++
# Elapsed time:  2.3869741809994593
# Stopped at epoch:  51
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [10] | 12 ++++++++++++++++++
# Elapsed time:  2.210324536999906
# Stopped at epoch:  60
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [10] | 13 ++++++++++++++++++
# Elapsed time:  1.4109189489990968
# Stopped at epoch:  29
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [10] | 14 ++++++++++++++++++
# Elapsed time:  1.432104943000013
# Stopped at epoch:  35
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# +++++++++++ Dataset [10] | 15 ++++++++++++++++++
# Elapsed time:  2.256644355999015
# Stopped at epoch:  50
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [10] | 16 ++++++++++++++++++
# Elapsed time:  0.6445570569994743
# Stopped at epoch:  12
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [10] | 17 ++++++++++++++++++
# Elapsed time:  0.8017053419989679
# Stopped at epoch:  18
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [10] | 18 ++++++++++++++++++
# Elapsed time:  0.6984505700002046
# Stopped at epoch:  16
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [10] | 19 ++++++++++++++++++
# Elapsed time:  0.6175650349996431
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [10] | 20 ++++++++++++++++++
# Elapsed time:  0.5349104260003514
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [10] | 21 ++++++++++++++++++
# Elapsed time:  0.572866835998866
# Stopped at epoch:  9
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [10] | 22 ++++++++++++++++++
# Elapsed time:  2.6965507730001264
# Stopped at epoch:  71
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 26ms/step
# +++++++++++ Dataset [10] | 23 ++++++++++++++++++
# Elapsed time:  1.1644400039986067
# Stopped at epoch:  26
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [10] | 24 ++++++++++++++++++
# Elapsed time:  2.6425571399995533
# Stopped at epoch:  60
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [10] | 25 ++++++++++++++++++
# Elapsed time:  2.1654500679997
# Stopped at epoch:  48
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [10] | 26 ++++++++++++++++++
# Elapsed time:  0.5398251990009157
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [10] | 27 ++++++++++++++++++
# Elapsed time:  2.8824311179996585
# Stopped at epoch:  77
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# +++++++++++ Dataset [10] | 28 ++++++++++++++++++
# Elapsed time:  2.0678992949997337
# Stopped at epoch:  45
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [10] | 29 ++++++++++++++++++
# Elapsed time:  1.957358325998939
# Stopped at epoch:  37
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [10] | 30 ++++++++++++++++++

# %%
tester.DisplayBetterResults('mse_sup')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 tester.DisplayBetterResults('mse_sup')
#
# NameError: name 'tester' is not defined
