# %%
import os

os.chdir("./content")

lm_dir = "tf-levenberg-marquardt"
if not os.path.exists(lm_dir):
  # !git clone https://github.com/fabiodimarco/$lm_dir

os.chdir(lm_dir)
# Out:
# Cloning into 'tf-levenberg-marquardt'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 53 (delta 31), reused 29 (delta 14), pack-reused 0
# Receiving objects: 100% (53/53), 32.99 KiB | 11.00 MiB/s, done.
# Resolving deltas: 100% (31/31), done.

# %%
# !pip install --upgrade pip
# !pip install tensorflow 
# !pip install openpyxl
# Out:
# Requirement already satisfied: pip in /usr/local/python/3.10.13/lib/python3.10/site-packages (23.3.2)
# Requirement already satisfied: tensorflow in /usr/local/python/3.10.13/lib/python3.10/site-packages (2.15.0.post1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (1.26.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (0.35.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.26.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/codespace/.local/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)
# Requirement already satisfied: openpyxl in /usr/local/python/3.10.13/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/python/3.10.13/lib/python3.10/site-packages (from openpyxl) (1.1.0)

# %%
import numpy as np
import pandas as pd
from scipy.stats import zscore
from sklearn.preprocessing import MaxAbsScaler

def peaks(grid):
    x = np.linspace(-2, 2, grid)
    y = np.linspace(-2, 2, grid)
    x, y = np.meshgrid(x, y)
    z = 3*(1-x)**2 * np.exp(-(x**2) - (y+1)**2) - 10*(x/5 - x**3 - y**5) * np.exp(-x**2 - y**2) - 1/3 * np.exp(-(x+1)**2 - y**2)
    return x, y, z

def create_dataframe(grid):
   x, y, z = peaks(grid)
   data = {'X': x.flatten(), 'Y': y.flatten(), 'Z': z.flatten()}
   df = pd.DataFrame(data)
   return df

# %%
df_25 = create_dataframe(grid=5)
df_1000 = create_dataframe(grid=32)

# %%
def split_df(df):
    # df = df.sample(frac=1).reset_index(drop=True)  # Randomiza as linhas
    _input = np.vstack([df['X'], df['Y']]).T
    _output = np.array(df['Z'])
    return (_input, _output)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import levenberg_marquardt as lm
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
from sklearn.metrics import r2_score, mean_squared_error
from keras import regularizers
from keras import initializers

class TrainWithSmallDataset:
    def __init__(self, batch_size=1000, store=25):
        self.batch_size = batch_size
        self.betters = []
        self.store = store

    def create_dataset(self, input, output):
      input = tf.expand_dims(tf.cast(input, tf.float32), axis=-1)
      output = tf.expand_dims(tf.cast(output, tf.float32), axis=-1)

      dataset = tf.data.Dataset.from_tensor_slices((input, output))
      dataset = dataset.shuffle(len(input))
      dataset = dataset.batch(self.batch_size).cache()
      dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
      return (dataset, input, output)


    def split_dataset(self, input, output, sup_input, sup_output):

      input_train, input_vt, output_train, output_vt = train_test_split(input, output, test_size=0.3, shuffle = True)
      input_val, input_test, output_val, output_test = train_test_split(input_vt, output_vt, test_size=0.5, shuffle = True)

      self.train_dataset, self.train_input, self.train_output = self.create_dataset(input_train, output_train)
      self.val_dataset, self.val_input, self.val_output = self.create_dataset(input_val, output_val)
      self.test_dataset, self.test_input, self.test_output = self.create_dataset(input_test, output_test)
      self.vt_dataset, self.vt_input, self.vt_output = self.create_dataset(input_vt, output_vt)
      self.sup_dataset, self.sup_input, self.sup_output = self.create_dataset(sup_input, sup_output)
      self.dataset, self.input, self.output = self.create_dataset(input, output)

      self._train = (input_train, output_train)
      self._vt = (input_vt, output_vt)
      self._val = (input_val, output_val)
      self._test = (input_test, output_test)

    def create_model(self, input_size=2, sumary=False):
      regularizer = regularizers.L2(0.2)
      initializer = initializers.RandomUniform(minval=-0.5, maxval=0.5, seed=np.random.randint(1, 10000))

      self.model = tf.keras.Sequential([
          tf.keras.layers.Dense(30,
                                activation='tanh',
                                input_shape=(input_size,),
                                kernel_regularizer=regularizer,
                                kernel_initializer=initializer,
                                ),
          tf.keras.layers.Dense(16,
                                activation='tanh',
                                kernel_regularizer=regularizer,
                                kernel_initializer=initializer,
                                ),
          tf.keras.layers.Dense(1,
                                activation='linear',
                                kernel_regularizer=regularizer,
                                kernel_initializer=initializer,
        )])

      if (sumary == True):
        self.model.summary()

      self.model.compile(
          optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
          loss=tf.keras.losses.MeanSquaredError())

      self.lm_model = lm.ModelWrapper(
          tf.keras.models.clone_model(self.model))

      self.lm_model.compile(
          optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
          loss=lm.MeanSquaredError())

    def train_using_lm(self, train_dataset, epochs=1000):
      early_stopping_monitor = EarlyStopping(monitor='val_loss',
                                              patience=6,
                                              restore_best_weights=True)

      t2_start = time.perf_counter()
      self.results = self.lm_model.fit(train_dataset,
                                            epochs=epochs,
                                            validation_data=self.val_dataset,
                                            callbacks=[early_stopping_monitor],
                                            verbose=0)
      t2_stop = time.perf_counter()
      print("Elapsed time: ", t2_stop - t2_start)
      print ("Stopped at epoch: ", early_stopping_monitor.stopped_epoch)

    def get_metrics(self):
          self.sup_prediction = self.lm_model.predict(self.sup_input)
          self.test_prediction = self.lm_model.predict(self.test_input)

          pred = self.lm_model.predict(self.input).flatten()
          test_pred = self.test_prediction.flatten()
          val_pred = self.lm_model.predict(self.val_input).flatten()
          vt_pred = self.lm_model.predict(self.vt_input).flatten()
          sup_pred = self.sup_prediction.flatten()

          r2 = r2_score(self.output, pred)
          r2_test = r2_score(self.test_output, test_pred)
          r2_val = r2_score(self.val_output, val_pred)
          r2_vt = r2_score(self.vt_output, vt_pred)
          r2_sup = r2_score(self.sup_output, sup_pred)

          mse = mean_squared_error(self.output, pred)
          mse_test = mean_squared_error(self.test_output, test_pred)
          mse_val = mean_squared_error(self.val_output, val_pred)
          mse_vt = mean_squared_error(self.vt_output, vt_pred)
          mse_sup = mean_squared_error(self.sup_output, sup_pred)

          metrics = {
                          'r2': r2,
                          'r2_sup': r2_sup,
                          'r2_test': r2_test,
                          'r2_val': r2_val,
                          'r2_vt': r2_vt,
                          'mse': mse,
                          'mse_sup': mse_sup,
                          'mse_test': mse_test,
                          'mse_val': mse_val,
                          'mse_vt': mse_vt
                          }

          return metrics


    def plot_results(self):
      fig = plt.figure(figsize=(18, 6))
      ax0 = fig.add_subplot(1, 3, 1, projection='3d')
      ax2 = fig.add_subplot(1, 3, 2, projection='3d')
      ax1 = fig.add_subplot(1, 3, 3)

      ax0.set_title('Superficie Fit')
      ax0.scatter(self.sup_input[:, 0], self.sup_input[:, 1], self.sup_prediction, c='r', marker='s', label="lm")
      ax0.scatter(self.sup_input[:, 0], self.sup_input[:, 1], self.sup_output, c='b', marker='o', label="reference")
      ax0.legend()

      ax2.set_title('Teste Fit')
      ax2.scatter(self.test_input[:, 0], self.test_input[:, 1], self.test_prediction, c='r', marker='s', label="lm")
      ax2.scatter(self.test_input[:, 0], self.test_input[:, 1], self.test_output, c='b', marker='o', label="reference")
      ax2.legend()

      ax1.plot(self.results.history['loss'], label='Erro Treino')
      ax1.plot(self.results.history['val_loss'], label='Erro validação')
      ax1.set_title('Histórico de Treinamento')
      ax1.set_ylabel('Função de Custo')
      ax1.set_xlabel('Épocas de Treinamento')
      ax1.legend(['Erro Treino', 'Erro validação'])

      return(fig)
# Out:
# 2024-01-31 01:48:15.025261: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-31 01:48:15.056654: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-31 01:48:15.056682: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-31 01:48:15.057855: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-31 01:48:15.063470: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-31 01:48:15.064369: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-31 01:48:15.936634: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from keras import saving
from keras import models
import pickle

class Tester:
  def __init__(self, run_times=500, dataset_run_times=10):
    self.run_times = run_times
    self.better_metrics = {}
    self.dataset_run_times = dataset_run_times
    self.input_25, self.output_25 = split_df(df_25)
    self.input_1000, self.output_1000 = split_df(df_1000)

  def PrepareTraining(self):
    trainer = TrainWithSmallDataset()
    trainer.split_dataset(self.input_25, self.output_25, self.input_1000, self.output_1000)
    return (trainer)

  def Train(self, trainer, epochs=1000):
    trainer.create_model()
    trainer.train_using_lm(trainer.train_dataset, epochs=epochs)
    return(trainer.get_metrics(), trainer.lm_model)

  def SaveModelWeights(self, model, fileName):
    path = f"../models/{fileName}.keras"
    open(path,'w').close()
    model.save_weights(path)
  
  def SaveFigs(self, trainer, fileName):
    path = f"../results/{fileName}.png" 
    open(path,'w').close()
    figure = trainer.plot_results()
    figure.savefig(path)
    plt.close(figure)

  def SaveDataset(self, trainer, fileName):
    path = f"../dataset/{fileName}.pkl" 
    with open(path, 'wb') as f:
      pickle.dump((trainer._train, trainer._vt, trainer._val, trainer._test), f)
  
  def LoadDataset(self, fileName, trainer=None):
    path = f"../dataset/{fileName}.pkl" 
    with open(path, 'rb') as f:
      _train, _vt, _val, _test = pickle.load(f)
    trainer._train, trainer._vt, trainer._val, trainer._test = _train, _vt, _val, _test

  def LoopWeights(self, sort_by, model_boundarie, trainer, idx):
    better_model = 0
    save = False

    for i in range(self.run_times):
      print (f"+++++++++++ Dataset [{idx + 1}] | {i + 1} ++++++++++++++++++")
      metrics, model = self.Train(trainer)
      if (metrics[sort_by] <= model_boundarie): # should be >= to acsending metrics
        fileName = f"model_{idx}_{better_model}"
        self.SaveModelWeights(model, fileName)
        self.SaveFigs(trainer, fileName)
        self.better_metrics[fileName] = metrics
        better_model += 1
        save = True
    
    return(save)

  # brief: for each dataset
  def LoopDataset(self, sort_by, model_boundarie):
    for j in range(self.dataset_run_times):
      trainer = self.PrepareTraining() # split dataset
      if (self.LoopWeights(sort_by, model_boundarie, trainer, j) == True):
        self.SaveDataset(trainer, f"dataset_{j}")
        self.DisplayBetterResults('mse_sup', j)
      self.better_metrics = {}

  def DisplayBetterResults(self, sort_by, dataset=0):
    df = pd.DataFrame.from_dict(self.better_metrics, orient='index')
    df = df.sort_values([sort_by])
    display(df)
    excel_path = f'../results/metrics_{dataset}.xlsx'
    df.to_excel(excel_path, index=True)
    print(f"DataFrame salvo em {excel_path}")

# %% [markdown]
# # Treinando com 25 dados

# %%
tester = Tester(run_times=100, dataset_run_times=50)

# %%
tester.LoopDataset(sort_by='mse_sup', model_boundarie=2.5)
# Out:
# +++++++++++ Dataset [1] | 1 ++++++++++++++++++
# Elapsed time:  0.9065487009997923
# Stopped at epoch:  9
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 2 ++++++++++++++++++
# Elapsed time:  0.6266683900003045
# Stopped at epoch:  13
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# +++++++++++ Dataset [1] | 3 ++++++++++++++++++
# Elapsed time:  0.39923220599985143
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 4 ++++++++++++++++++
# Elapsed time:  2.395720105000237
# Stopped at epoch:  96
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 5 ++++++++++++++++++
# Elapsed time:  0.4212847630001306
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 6 ++++++++++++++++++
# Elapsed time:  0.4368227059999299
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 7 ++++++++++++++++++
# Elapsed time:  0.7025010940001266
# Stopped at epoch:  19
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 8 ++++++++++++++++++
# Elapsed time:  4.926143563000096
# Stopped at epoch:  200
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 9 ++++++++++++++++++
# Elapsed time:  0.4146875070000533
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 20ms/step
# +++++++++++ Dataset [1] | 10 ++++++++++++++++++
# Elapsed time:  2.163444279000032
# Stopped at epoch:  83
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 11 ++++++++++++++++++
# Elapsed time:  5.893851064999581
# Stopped at epoch:  237
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# +++++++++++ Dataset [1] | 12 ++++++++++++++++++
# Elapsed time:  0.423750347999885
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 13 ++++++++++++++++++
# Elapsed time:  0.4692022750000433
# Stopped at epoch:  10
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 14 ++++++++++++++++++
# Elapsed time:  0.4400013599997692
# Stopped at epoch:  9
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [1] | 15 ++++++++++++++++++
# Elapsed time:  0.6675318479997259
# Stopped at epoch:  19
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 16 ++++++++++++++++++
# Elapsed time:  1.9902275730000838
# Stopped at epoch:  72
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 17 ++++++++++++++++++
# Elapsed time:  1.8806082460000653
# Stopped at epoch:  73
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 18 ++++++++++++++++++
# Elapsed time:  6.153533433000121
# Stopped at epoch:  239
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 19 ++++++++++++++++++
# Elapsed time:  0.44678636099979485
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 20 ++++++++++++++++++
# Elapsed time:  0.37596829399990384
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 21 ++++++++++++++++++
# Elapsed time:  0.402351064999948
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 22 ++++++++++++++++++
# Elapsed time:  0.9318403570000555
# Stopped at epoch:  29
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 23 ++++++++++++++++++
# Elapsed time:  0.4310279259998424
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 24 ++++++++++++++++++
# Elapsed time:  3.9678751500000544
# Stopped at epoch:  157
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [1] | 25 ++++++++++++++++++
# Elapsed time:  0.3899502740000571
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 26 ++++++++++++++++++
# Elapsed time:  0.4007500339998842
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 27 ++++++++++++++++++
# Elapsed time:  2.6120860599999105
# Stopped at epoch:  101
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 28 ++++++++++++++++++
# Elapsed time:  0.42698009900004763
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 29 ++++++++++++++++++
# Elapsed time:  0.6770352650000859
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 30 ++++++++++++++++++
# Elapsed time:  3.9171717409999474
# Stopped at epoch:  155
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 31 ++++++++++++++++++
# Elapsed time:  0.3987806410000303
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 32 ++++++++++++++++++
# Elapsed time:  2.71694975399987
# Stopped at epoch:  107
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 33 ++++++++++++++++++
# Elapsed time:  4.262745951999932
# Stopped at epoch:  174
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 34 ++++++++++++++++++
# Elapsed time:  2.2455108129997825
# Stopped at epoch:  89
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 35 ++++++++++++++++++
# Elapsed time:  1.6413972219997959
# Stopped at epoch:  62
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 36 ++++++++++++++++++
# Elapsed time:  3.2186333020003985
# Stopped at epoch:  125
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 37 ++++++++++++++++++
# Elapsed time:  0.3977477620001082
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 38 ++++++++++++++++++
# Elapsed time:  2.391133566999997
# Stopped at epoch:  92
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 39 ++++++++++++++++++
# Elapsed time:  0.42628535599988027
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 40 ++++++++++++++++++
# Elapsed time:  0.3765047689998937
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 41 ++++++++++++++++++
# Elapsed time:  1.6586358479999035
# Stopped at epoch:  62
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 42 ++++++++++++++++++
# Elapsed time:  0.48699308200002633
# Stopped at epoch:  11
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# +++++++++++ Dataset [1] | 43 ++++++++++++++++++
# Elapsed time:  2.587324901000102
# Stopped at epoch:  101
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 44 ++++++++++++++++++
# Elapsed time:  3.832470507999915
# Stopped at epoch:  145
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 45 ++++++++++++++++++
# Elapsed time:  0.37912140700018426
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 46 ++++++++++++++++++
# Elapsed time:  1.6079960619999838
# Stopped at epoch:  60
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 47 ++++++++++++++++++
# Elapsed time:  0.42596020500013765
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 48 ++++++++++++++++++
# Elapsed time:  0.4107526439997855
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 49 ++++++++++++++++++
# Elapsed time:  0.39815236000004006
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 50 ++++++++++++++++++
# Elapsed time:  0.40597074200013594
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 51 ++++++++++++++++++
# Elapsed time:  3.118300958999953
# Stopped at epoch:  121
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 52 ++++++++++++++++++
# Elapsed time:  0.8122366749998946
# Stopped at epoch:  25
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 53 ++++++++++++++++++
# Elapsed time:  0.4139057669999602
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 54 ++++++++++++++++++
# Elapsed time:  0.4817389929999081
# Stopped at epoch:  10
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 55 ++++++++++++++++++
# Elapsed time:  0.7438947910000024
# Stopped at epoch:  20
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 56 ++++++++++++++++++
# Elapsed time:  0.42606145699983244
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 57 ++++++++++++++++++
# Elapsed time:  0.4327541560001009
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [1] | 58 ++++++++++++++++++
# Elapsed time:  3.6573755660001552
# Stopped at epoch:  141
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 59 ++++++++++++++++++
# Elapsed time:  0.4476533140000356
# Stopped at epoch:  9
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 60 ++++++++++++++++++
# Elapsed time:  1.6011693090003973
# Stopped at epoch:  56
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 61 ++++++++++++++++++
# Elapsed time:  0.42218354899978294
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 62 ++++++++++++++++++
# Elapsed time:  1.5401069169997754
# Stopped at epoch:  47
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 63 ++++++++++++++++++
# Elapsed time:  0.4047904109997944
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 64 ++++++++++++++++++
# Elapsed time:  7.040827913000157
# Stopped at epoch:  291
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 65 ++++++++++++++++++
# Elapsed time:  1.2477072040001076
# Stopped at epoch:  40
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [1] | 66 ++++++++++++++++++
# Elapsed time:  2.048595330000353
# Stopped at epoch:  75
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 67 ++++++++++++++++++
# Elapsed time:  0.4003287329996965
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 68 ++++++++++++++++++
# Elapsed time:  5.299302720000014
# Stopped at epoch:  219
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# +++++++++++ Dataset [1] | 69 ++++++++++++++++++
# Elapsed time:  0.4242604949999986
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 70 ++++++++++++++++++
# Elapsed time:  4.569717311999739
# Stopped at epoch:  181
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [1] | 71 ++++++++++++++++++
# Elapsed time:  0.479307523999978
# Stopped at epoch:  10
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 72 ++++++++++++++++++
# Elapsed time:  2.680187943999954
# Stopped at epoch:  109
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# +++++++++++ Dataset [1] | 73 ++++++++++++++++++
# Elapsed time:  5.463935812999807
# Stopped at epoch:  208
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 74 ++++++++++++++++++
# Elapsed time:  0.4356857130001117
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 75 ++++++++++++++++++
# Elapsed time:  1.7859271019997323
# Stopped at epoch:  69
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 76 ++++++++++++++++++
# Elapsed time:  0.4086474239998097
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 77 ++++++++++++++++++
# Elapsed time:  0.4568570500000533
# Stopped at epoch:  9
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 78 ++++++++++++++++++
# Elapsed time:  2.226447043999997
# Stopped at epoch:  80
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 79 ++++++++++++++++++
# Elapsed time:  0.4609441530001277
# Stopped at epoch:  9
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 80 ++++++++++++++++++
# Elapsed time:  2.6653754690000824
# Stopped at epoch:  96
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 81 ++++++++++++++++++
# Elapsed time:  2.9104245160001483
# Stopped at epoch:  120
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 82 ++++++++++++++++++
# Elapsed time:  0.41335666799977844
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# +++++++++++ Dataset [1] | 83 ++++++++++++++++++
# Elapsed time:  0.48818099200025244
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 84 ++++++++++++++++++
# Elapsed time:  0.4006806490001509
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 85 ++++++++++++++++++
# Elapsed time:  0.4653868919999695
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 86 ++++++++++++++++++
# Elapsed time:  0.42441936300019734
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 87 ++++++++++++++++++
# Elapsed time:  3.3218760569998267
# Stopped at epoch:  127
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 88 ++++++++++++++++++
# Elapsed time:  0.4036912740002663
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 89 ++++++++++++++++++
# Elapsed time:  5.867090011000073
# Stopped at epoch:  239
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 90 ++++++++++++++++++
# Elapsed time:  0.4414919269997881
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 91 ++++++++++++++++++
# Elapsed time:  0.38942837699960364
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 92 ++++++++++++++++++
# Elapsed time:  3.4508272910002233
# Stopped at epoch:  141
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 93 ++++++++++++++++++
# Elapsed time:  0.4456247500002064
# Stopped at epoch:  9
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 94 ++++++++++++++++++
# Elapsed time:  0.4728978240000288
# Stopped at epoch:  10
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [1] | 95 ++++++++++++++++++
# Elapsed time:  5.077555360000133
# Stopped at epoch:  200
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [1] | 96 ++++++++++++++++++
# Elapsed time:  0.46797207899999194
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 97 ++++++++++++++++++
# Elapsed time:  3.213315225000315
# Stopped at epoch:  131
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 98 ++++++++++++++++++
# Elapsed time:  0.4303819920000933
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [1] | 99 ++++++++++++++++++
# Elapsed time:  0.4080114120001781
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# +++++++++++ Dataset [1] | 100 ++++++++++++++++++
# Elapsed time:  0.48946887000010975
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
#                  r2    r2_sup    r2_test    r2_val     r2_vt       mse  \
# model_0_1  0.796237  0.645782 -54.785398  0.575678  0.348470  0.855152
# model_0_0  0.801788  0.641797 -41.216368  0.534611  0.367093  0.831853
# model_0_3  0.807732  0.634117 -46.472933  0.588798  0.396983  0.806906
# model_0_2  0.798045  0.633252 -58.664679  0.574396  0.330523  0.847561
# model_0_4  0.792860  0.632162 -48.871033  0.581765  0.379839  0.869321
#
#             mse_sup  mse_test   mse_val    mse_vt
# model_0_1  2.368656  1.864877  3.193097  2.528987
# model_0_0  2.395304  1.411271  3.502131  2.456701
# model_0_3  2.446659  1.586996  3.094366  2.340681
# model_0_2  2.452447  1.994559  3.202742  2.598651
# model_0_4  2.459737  1.667163  3.147286  2.407225
# DataFrame salvo em ../results/metrics_0.xlsx
# +++++++++++ Dataset [2] | 1 ++++++++++++++++++
# Elapsed time:  0.5385179029999563
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [2] | 2 ++++++++++++++++++
# Elapsed time:  2.782819331000155
# Stopped at epoch:  113
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 3 ++++++++++++++++++
# Elapsed time:  0.4935364349998963
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [2] | 4 ++++++++++++++++++
# Elapsed time:  0.4286501229998976
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [2] | 5 ++++++++++++++++++
# Elapsed time:  0.444998164000026
# Stopped at epoch:  9
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [2] | 6 ++++++++++++++++++
# Elapsed time:  0.5019234119999965
# Stopped at epoch:  11
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [2] | 7 ++++++++++++++++++
# Elapsed time:  0.5955011189998913
# Stopped at epoch:  16
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 8 ++++++++++++++++++
# Elapsed time:  0.9945744209999248
# Stopped at epoch:  34
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# +++++++++++ Dataset [2] | 9 ++++++++++++++++++
# Elapsed time:  0.44671492800034684
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [2] | 10 ++++++++++++++++++
# Elapsed time:  0.5160599400001047
# Stopped at epoch:  10
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [2] | 11 ++++++++++++++++++
# Elapsed time:  0.6820868070003598
# Stopped at epoch:  17
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [2] | 12 ++++++++++++++++++
# Elapsed time:  0.5705332140000792
# Stopped at epoch:  14
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [2] | 13 ++++++++++++++++++
# Elapsed time:  1.5188721629997417
# Stopped at epoch:  56
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [2] | 14 ++++++++++++++++++
# Elapsed time:  0.7896980800001074
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 15 ++++++++++++++++++
# Elapsed time:  0.5978695449998668
# Stopped at epoch:  12
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [2] | 16 ++++++++++++++++++
# Elapsed time:  0.942404764999992
# Stopped at epoch:  31
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [2] | 17 ++++++++++++++++++
# Elapsed time:  0.4298766130000331
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [2] | 18 ++++++++++++++++++
# Elapsed time:  0.41539795400012736
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [2] | 19 ++++++++++++++++++
# Elapsed time:  0.43768191299977843
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [2] | 20 ++++++++++++++++++
# Elapsed time:  0.4779570630003036
# Stopped at epoch:  10
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [2] | 21 ++++++++++++++++++
# Elapsed time:  0.5993458569996619
# Stopped at epoch:  14
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [2] | 22 ++++++++++++++++++
# Elapsed time:  0.46739921000016693
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [2] | 23 ++++++++++++++++++
# Elapsed time:  0.4689662109999517
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [2] | 24 ++++++++++++++++++
# Elapsed time:  0.4153720159997647
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [2] | 25 ++++++++++++++++++
# Elapsed time:  0.4605696779999562
# Stopped at epoch:  9
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [2] | 26 ++++++++++++++++++
# Elapsed time:  0.41675622699995074
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [2] | 27 ++++++++++++++++++
# Elapsed time:  0.4261453449998953
# Stopped at epoch:  8
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [2] | 28 ++++++++++++++++++
# Elapsed time:  0.40517831800025306
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [2] | 29 ++++++++++++++++++
# Elapsed time:  1.588676636999935
# Stopped at epoch:  60
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [2] | 30 ++++++++++++++++++
# Elapsed time:  0.41310952000003454
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# ...
# Elapsed time:  0.5977152870000282
# Stopped at epoch:  6
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [50] | 59 ++++++++++++++++++
# Elapsed time:  1.0211813660007465
# Stopped at epoch:  27
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [50] | 60 ++++++++++++++++++
# Elapsed time:  1.2234308179995423
# Stopped at epoch:  35
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [50] | 61 ++++++++++++++++++
# Elapsed time:  1.387356102000922
# Stopped at epoch:  42
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [50] | 62 ++++++++++++++++++
# Elapsed time:  1.7348466189996543
# Stopped at epoch:  59
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [50] | 63 ++++++++++++++++++
# Elapsed time:  2.3818718630009243
# Stopped at epoch:  86
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# +++++++++++ Dataset [50] | 64 ++++++++++++++++++
# Elapsed time:  0.5900273600000219
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [50] | 65 ++++++++++++++++++
# Elapsed time:  2.5152479789994686
# Stopped at epoch:  92
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [50] | 66 ++++++++++++++++++
# Elapsed time:  1.369776223998997
# Stopped at epoch:  33
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [50] | 67 ++++++++++++++++++
# Elapsed time:  2.965689847000249
# Stopped at epoch:  113
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [50] | 68 ++++++++++++++++++
# Elapsed time:  1.1275724480001372
# Stopped at epoch:  31
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [50] | 69 ++++++++++++++++++
# Elapsed time:  1.74382533500102
# Stopped at epoch:  60
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [50] | 70 ++++++++++++++++++
# Elapsed time:  2.2788964079991274
# Stopped at epoch:  81
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [50] | 71 ++++++++++++++++++
# Elapsed time:  1.2655128260012134
# Stopped at epoch:  36
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [50] | 72 ++++++++++++++++++
# Elapsed time:  1.2800961540015123
# Stopped at epoch:  34
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [50] | 73 ++++++++++++++++++
# Elapsed time:  1.0429642389990477
# Stopped at epoch:  27
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [50] | 74 ++++++++++++++++++
# Elapsed time:  1.7191374920003
# Stopped at epoch:  58
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [50] | 75 ++++++++++++++++++
# Elapsed time:  1.104285969000557
# Stopped at epoch:  30
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [50] | 76 ++++++++++++++++++
# Elapsed time:  0.5918602760011709
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [50] | 77 ++++++++++++++++++
# Elapsed time:  1.7222802270007378
# Stopped at epoch:  58
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [50] | 78 ++++++++++++++++++
# Elapsed time:  3.0029965239991725
# Stopped at epoch:  111
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [50] | 79 ++++++++++++++++++
# Elapsed time:  1.2364812959986011
# Stopped at epoch:  37
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [50] | 80 ++++++++++++++++++
# Elapsed time:  1.6378743240002223
# Stopped at epoch:  56
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [50] | 81 ++++++++++++++++++
# Elapsed time:  1.4112971979993745
# Stopped at epoch:  45
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [50] | 82 ++++++++++++++++++
# Elapsed time:  2.0420686209999985
# Stopped at epoch:  72
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [50] | 83 ++++++++++++++++++
# Elapsed time:  1.2974470050012314
# Stopped at epoch:  37
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# +++++++++++ Dataset [50] | 84 ++++++++++++++++++
# Elapsed time:  0.6018066470005579
# Stopped at epoch:  9
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [50] | 85 ++++++++++++++++++
# Elapsed time:  1.7065769200016803
# Stopped at epoch:  58
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [50] | 86 ++++++++++++++++++
# Elapsed time:  1.0418415240001195
# Stopped at epoch:  29
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [50] | 87 ++++++++++++++++++
# Elapsed time:  1.8086085569993884
# Stopped at epoch:  63
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [50] | 88 ++++++++++++++++++
# Elapsed time:  1.7047644029989897
# Stopped at epoch:  59
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [50] | 89 ++++++++++++++++++
# Elapsed time:  1.2816508230007457
# Stopped at epoch:  37
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [50] | 90 ++++++++++++++++++
# Elapsed time:  1.425244265999936
# Stopped at epoch:  44
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [50] | 91 ++++++++++++++++++
# Elapsed time:  1.6596946270001354
# Stopped at epoch:  57
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [50] | 92 ++++++++++++++++++
# Elapsed time:  1.4926975250000396
# Stopped at epoch:  43
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# +++++++++++ Dataset [50] | 93 ++++++++++++++++++
# Elapsed time:  2.7650487479986623
# Stopped at epoch:  107
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [50] | 94 ++++++++++++++++++
# Elapsed time:  1.075844375000088
# Stopped at epoch:  20
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [50] | 95 ++++++++++++++++++
# Elapsed time:  1.2553448750004463
# Stopped at epoch:  39
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# +++++++++++ Dataset [50] | 96 ++++++++++++++++++
# Elapsed time:  1.7249299089999113
# Stopped at epoch:  51
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [50] | 97 ++++++++++++++++++
# Elapsed time:  1.667734811999253
# Stopped at epoch:  53
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [50] | 98 ++++++++++++++++++
# Elapsed time:  4.615613604999453
# Stopped at epoch:  183
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# +++++++++++ Dataset [50] | 99 ++++++++++++++++++
# Elapsed time:  2.5919355650003126
# Stopped at epoch:  95
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# +++++++++++ Dataset [50] | 100 ++++++++++++++++++
# Elapsed time:  0.6309927929996775
# Stopped at epoch:  7
# 32/32 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
#                   r2    r2_sup    r2_test    r2_val     r2_vt       mse  \
# model_49_0  0.857989  0.637315 -12.222324  0.563419  0.490712  0.595992
#
#              mse_sup  mse_test   mse_val    mse_vt
# model_49_0  2.425278  0.911798  1.751126  1.331462
# DataFrame salvo em ../results/metrics_49.xlsx
