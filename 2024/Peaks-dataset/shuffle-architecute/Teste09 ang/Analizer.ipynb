# %%
import pandas as pd
import numpy as np

def read_excel(file_name):
    df = pd.read_excel(file_name)
    return df

def read_txt(file_name):
    file = open(file_name)
    lines = file.readlines()
    return(lines[0])

# %%
import os
import glob

def get_files(subfolder, extension):
    dir = f"{os.getcwd()}/content/{subfolder}/"
    tables = glob.glob(f"{dir}*.{extension}")
    return tables

# %%
class Analizer:
    def __init__(self):
        self.results = get_files(subfolder="results", extension="xlsx")
        self.results_df = pd.DataFrame()
    
    def has_minimum_requirements(self, df, sort_by="r2", boundary=0.75):
        sorted_df = df.sort_values(by=sort_by, ascending=False)
        top_r2 = sorted_df.head(1)[sort_by].values[0]
        if top_r2 < boundary:
            return False
        return True
    
    def concatenate_df(self, df, architecture):
        if self.has_minimum_requirements(df):
            df['Architecture'] = architecture
            df = df.rename(columns={'Unnamed: 0': 'model'})
            self.results_df = pd.concat([self.results_df, df], ignore_index=True) 

    def create_results_df(self):
        for file in self.results:
            df = read_excel(file)
            architecture = read_txt(file.replace(".xlsx", ".txt"))
            self.concatenate_df(df, architecture)
        self.results_df = self.results_df.sort_values(by="r2", ascending=False, ignore_index=True)

    def discard_below_average(self, sort_by):
        column_mean = self.results_df[sort_by].mean()      
        self.results_df = self.results_df[self.results_df[sort_by] >= column_mean]
    
    def discard_high_standard_deviation(self):
        r2_val, r2_test = self.results_df['r2_val'], self.results_df['r2_test']
        std_devs = np.abs(r2_val - r2_test)
        mean_std_dev = std_devs.mean()
        self.results_df = self.results_df[std_devs < mean_std_dev]

    def clean_folder(self, subfolder, extension, remove_last=True):
        files = get_files(subfolder, extension)
        models = self.results_df["model"]
        if (remove_last):
            models = models.apply(lambda x: '_'.join(x.rsplit('_', 1)[:-1]))
        for file in files:
            file_name = os.path.basename(file).split('.')[0]
            file_parts = file_name.split('_')            
            dataset_model = f"model_{file_parts[1]}_{file_parts[2]}" 
            if (remove_last == False):
                dataset_model = (f"{dataset_model}_{file_parts[3]}")
            if dataset_model not in models.values:
                os.remove(file)
        
    def Analize(self):
        self.create_results_df()
        self.discard_below_average(sort_by="r2")
        self.discard_below_average(sort_by="r2_vt")
        self.discard_high_standard_deviation()
        self.results_df.to_excel(f"better_results.xlsx", index=True)
        display(self.results_df)

# %%
analize = Analizer()
analize.Analize()
analize.clean_folder(subfolder="dataset", extension="pkl")
analize.clean_folder(subfolder="results", extension="xlsx")
analize.clean_folder(subfolder="results", extension="xlsx")
analize.clean_folder(subfolder="results", extension="png", remove_last=False)
analize.clean_folder(subfolder="models", extension="keras", remove_last=False)
# Out:
#             model        r2    r2_sup   r2_test    r2_val     r2_vt       mse  \
# 18   model_4_9_14  0.999463  0.741669  0.999908  0.997468  0.999375  0.002252
# 19    model_4_9_6  0.999463  0.741669  0.999908  0.997468  0.999375  0.002252
# 20   model_4_9_23  0.999463  0.741669  0.999908  0.997468  0.999375  0.002252
# 21   model_4_9_12  0.999463  0.741669  0.999908  0.997468  0.999375  0.002252
# 22   model_4_9_10  0.999463  0.741669  0.999908  0.997468  0.999375  0.002252
# 23    model_4_9_9  0.999463  0.741669  0.999908  0.997468  0.999375  0.002252
# 24    model_4_9_8  0.999463  0.741669  0.999908  0.997468  0.999375  0.002252
# 19   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 20   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 21   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 22   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 23   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 24   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 25   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 26   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 27   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 28   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 29   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 30   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 31   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 32   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 33   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 34   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 35   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 36   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 39   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 44   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 45   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 46   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 48   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 49   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 87   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 93   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 99   Hidden Size=[30, 21], regularizer=0.2, learnin...
# 119  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 120  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 121  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 122  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 123  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 124  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 125  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 126  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 127  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 128  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 129  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 130  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 131  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 132  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 133  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 134  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 135  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 136  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 137  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 138  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 139  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 140  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 141  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 142  Hidden Size=[30, 21], regularizer=0.5, learnin...
# 143  Hidden Size=[30, 21], regularizer=0.5, learnin...
